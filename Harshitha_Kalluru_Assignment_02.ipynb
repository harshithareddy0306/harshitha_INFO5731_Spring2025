# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Monday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**
#
# **Please check that the link you submitted can be opened and points to the correct assignment.**

# %% [markdown]
# # Question 1 (25 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
#
# (3) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (4) Collect all the information of the 904 narrators in the Densho Digital Repository.
#
# (5)**Collect a total of 10000 reviews** of the top 100 most popular software from G2 and Capterra.

# %%
import requests
import csv
from bs4 import BeautifulSoup

def get_total_reviews(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    total_reviews_str = soup.find('div', {'class': 'header'}).get_text().split()[0]
    total_reviews = int(total_reviews_str.replace(',', ''))
    return total_reviews

def scrape_reviews(url, csv_filename):
    total_reviews = get_total_reviews(url)

    with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(['Review'])

        for page in range(1, min(1001, total_reviews // 10 + 2)):
            page_url = f'{url}&start={10*(page-1)}'
            page_response = requests.get(page_url)
            page_soup = BeautifulSoup(page_response.content, 'html.parser')
            reviews = page_soup.find_all('div', {'class': 'text show-more__control'})

            for review in reviews:
                review_text = review.get_text().strip()
                csv_writer.writerow([review_text])

if __name__ == "__main__":
    imdb_url = 'https://www.imdb.com/title/tt10954600/reviews?ref_=tt_urv'
    csv_filename = 'Antman_reviews.csv'
    scrape_reviews(imdb_url, csv_filename)

# %%
# Import the necessary library
import pandas as pd

# Load the CSV file data into a DataFrame
df = pd.read_csv('Antman_reviews.csv')

# Display the first 100 rows of the DataFrame
print(df.head(100))
# Out:
#     Unnamed: 0                                             Review
# 0            1  a huge fan first one almost big fan second one...
# 1            2  after entri phase pas without much set next bi...
# 2            3  well happen the mcu run ga the last mcu film l...
# 3            4  well ill start say wasnt bad movi it wasnt gre...
# 4            5  i enjoy watch quantumania it mostli solid fair...
# ..         ...                                                ...
# 95          96  thi film unspeak badit actual wors etern becau...
# 96          97  a fun onei terrif time watch antman wasp quant...
# 97          98  a mani other point far heyday peak mcu movi an...
# 98          99  the mcu current state absolut mess up endgam w...
# 99         100  so im go say great marvel film howev i also wo...
#
# [100 rows x 2 columns]

# %% [markdown]
# # Question 2 (15 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Your code here

# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.11/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.11/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (4.67.1)

# %%
# Write your code here
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from textblob import Word
import re
import pandas as pd

nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Noise Removal
df['Reviews after Noise Removal'] = df['Review'].str.replace('[^\w\s]', '')
df['Reviews after Noise Removal'] = df['Reviews after Noise Removal'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x))
df.head()
# Out:
#    Unnamed: 0                                             Review  \
# 0           1  a huge fan first one almost big fan second one...
# 1           2  after entri phase pas without much set next bi...
# 2           3  well happen the mcu run ga the last mcu film l...
# 3           4  well ill start say wasnt bad movi it wasnt gre...
# 4           5  i enjoy watch quantumania it mostli solid fair...
#
#                          Reviews after Noise Removal  \
# 0  a huge fan first one almost big fan second one...
# 1  after entri phase pas without much set next bi...
# 2  well happen the mcu run ga the last mcu film l...
# 3  well ill start say wasnt bad movi it wasnt gre...
# 4  i enjoy watch quantumania it mostli solid fair...
#
#                                 After digits removal  \
# 0  a huge fan first one almost big fan second one...
# 1  after entri phase pas without much set next bi...
# 2  well happen the mcu run ga the last mcu film l...
# 3  well ill start say wasnt bad movi it wasnt gre...
# 4  i enjoy watch quantumania it mostli solid fair...
#
#                                    Stopwords Removal  \
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pas without much set next big bad ...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...
#
#                                           Lower Case  \
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pas without much set next big bad ...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...
#
#                                       After Stemming  \
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pa without much set next big bad m...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...
#
#                                  After Lemmatization  \
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pa without much set next big bad m...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...
#
#                                         cleaned_text
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pa without much set next big bad m...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...

# %%
# Remove Digits
df['After digits removal'] = df['Reviews after Noise Removal'].apply(lambda y: ''.join([i for i in y if not i.isdigit()]))
df.head()
# Out:
#    Unnamed: 0                                             Review  \
# 0           1  a huge fan first one almost big fan second one...
# 1           2  after entri phase pas without much set next bi...
# 2           3  well happen the mcu run ga the last mcu film l...
# 3           4  well ill start say wasnt bad movi it wasnt gre...
# 4           5  i enjoy watch quantumania it mostli solid fair...
#
#                          Reviews after Noise Removal  \
# 0  a huge fan first one almost big fan second one...
# 1  after entri phase pas without much set next bi...
# 2  well happen the mcu run ga the last mcu film l...
# 3  well ill start say wasnt bad movi it wasnt gre...
# 4  i enjoy watch quantumania it mostli solid fair...
#
#                                 After digits removal
# 0  a huge fan first one almost big fan second one...
# 1  after entri phase pas without much set next bi...
# 2  well happen the mcu run ga the last mcu film l...
# 3  well ill start say wasnt bad movi it wasnt gre...
# 4  i enjoy watch quantumania it mostli solid fair...

# %%
# Stopwords Removal
s = stopwords.words('english')
df['Stopwords Removal'] = df['After digits removal'].apply(lambda x: " ".join(x for x in x.split() if x not in s))
df.head()
# Out:
#    Unnamed: 0                                             Review  \
# 0           1  a huge fan first one almost big fan second one...
# 1           2  after entri phase pas without much set next bi...
# 2           3  well happen the mcu run ga the last mcu film l...
# 3           4  well ill start say wasnt bad movi it wasnt gre...
# 4           5  i enjoy watch quantumania it mostli solid fair...
#
#                          Reviews after Noise Removal  \
# 0  a huge fan first one almost big fan second one...
# 1  after entri phase pas without much set next bi...
# 2  well happen the mcu run ga the last mcu film l...
# 3  well ill start say wasnt bad movi it wasnt gre...
# 4  i enjoy watch quantumania it mostli solid fair...
#
#                                 After digits removal  \
# 0  a huge fan first one almost big fan second one...
# 1  after entri phase pas without much set next bi...
# 2  well happen the mcu run ga the last mcu film l...
# 3  well ill start say wasnt bad movi it wasnt gre...
# 4  i enjoy watch quantumania it mostli solid fair...
#
#                                    Stopwords Removal
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pas without much set next big bad ...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...

# %%
# Convert to Lower Case
df['Lower Case'] = df['Stopwords Removal'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df.head()
# Out:
#    Unnamed: 0                                             Review  \
# 0           1  a huge fan first one almost big fan second one...
# 1           2  after entri phase pas without much set next bi...
# 2           3  well happen the mcu run ga the last mcu film l...
# 3           4  well ill start say wasnt bad movi it wasnt gre...
# 4           5  i enjoy watch quantumania it mostli solid fair...
#
#                          Reviews after Noise Removal  \
# 0  a huge fan first one almost big fan second one...
# 1  after entri phase pas without much set next bi...
# 2  well happen the mcu run ga the last mcu film l...
# 3  well ill start say wasnt bad movi it wasnt gre...
# 4  i enjoy watch quantumania it mostli solid fair...
#
#                                 After digits removal  \
# 0  a huge fan first one almost big fan second one...
# 1  after entri phase pas without much set next bi...
# 2  well happen the mcu run ga the last mcu film l...
# 3  well ill start say wasnt bad movi it wasnt gre...
# 4  i enjoy watch quantumania it mostli solid fair...
#
#                                    Stopwords Removal  \
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pas without much set next big bad ...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...
#
#                                           Lower Case
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pas without much set next big bad ...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...

# %%
# Stemming
stemmer = PorterStemmer()
df['After Stemming'] = df['Lower Case'].apply(lambda x: " ".join([stemmer.stem(word) for word in x.split()]))
df.head()
# Out:
#    Unnamed: 0                                             Review  \
# 0           1  a huge fan first one almost big fan second one...
# 1           2  after entri phase pas without much set next bi...
# 2           3  well happen the mcu run ga the last mcu film l...
# 3           4  well ill start say wasnt bad movi it wasnt gre...
# 4           5  i enjoy watch quantumania it mostli solid fair...
#
#                          Reviews after Noise Removal  \
# 0  a huge fan first one almost big fan second one...
# 1  after entri phase pas without much set next bi...
# 2  well happen the mcu run ga the last mcu film l...
# 3  well ill start say wasnt bad movi it wasnt gre...
# 4  i enjoy watch quantumania it mostli solid fair...
#
#                                 After digits removal  \
# 0  a huge fan first one almost big fan second one...
# 1  after entri phase pas without much set next bi...
# 2  well happen the mcu run ga the last mcu film l...
# 3  well ill start say wasnt bad movi it wasnt gre...
# 4  i enjoy watch quantumania it mostli solid fair...
#
#                                    Stopwords Removal  \
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pas without much set next big bad ...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...
#
#                                           Lower Case  \
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pas without much set next big bad ...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...
#
#                                       After Stemming
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pa without much set next big bad m...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...

# %%
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# Lemmatization
df['After Lemmatization'] = df['After Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df.head()
# Out:
#    Unnamed: 0                                             Review  \
# 0           1  a huge fan first one almost big fan second one...
# 1           2  after entri phase pas without much set next bi...
# 2           3  well happen the mcu run ga the last mcu film l...
# 3           4  well ill start say wasnt bad movi it wasnt gre...
# 4           5  i enjoy watch quantumania it mostli solid fair...
#
#                          Reviews after Noise Removal  \
# 0  a huge fan first one almost big fan second one...
# 1  after entri phase pas without much set next bi...
# 2  well happen the mcu run ga the last mcu film l...
# 3  well ill start say wasnt bad movi it wasnt gre...
# 4  i enjoy watch quantumania it mostli solid fair...
#
#                                 After digits removal  \
# 0  a huge fan first one almost big fan second one...
# 1  after entri phase pas without much set next bi...
# 2  well happen the mcu run ga the last mcu film l...
# 3  well ill start say wasnt bad movi it wasnt gre...
# 4  i enjoy watch quantumania it mostli solid fair...
#
#                                    Stopwords Removal  \
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pas without much set next big bad ...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...
#
#                                           Lower Case  \
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pas without much set next big bad ...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...
#
#                                       After Stemming  \
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pa without much set next big bad m...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...
#
#                                  After Lemmatization
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pa without much set next big bad m...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...

# %%
df['cleaned_text']= df['After Lemmatization']

# %%
# Save the cleaned data to a new column and CSV file
df.to_csv('Antman_reviews_cleaned.csv', index=False)

# Display the first few rows of the DataFrame
df.head()
# Out:
#    Unnamed: 0                                             Review  \
# 0           1  a huge fan first one almost big fan second one...
# 1           2  after entri phase pas without much set next bi...
# 2           3  well happen the mcu run ga the last mcu film l...
# 3           4  well ill start say wasnt bad movi it wasnt gre...
# 4           5  i enjoy watch quantumania it mostli solid fair...
#
#                          Reviews after Noise Removal  \
# 0  a huge fan first one almost big fan second one...
# 1  after entri phase pas without much set next bi...
# 2  well happen the mcu run ga the last mcu film l...
# 3  well ill start say wasnt bad movi it wasnt gre...
# 4  i enjoy watch quantumania it mostli solid fair...
#
#                                 After digits removal  \
# 0  a huge fan first one almost big fan second one...
# 1  after entri phase pas without much set next bi...
# 2  well happen the mcu run ga the last mcu film l...
# 3  well ill start say wasnt bad movi it wasnt gre...
# 4  i enjoy watch quantumania it mostli solid fair...
#
#                                    Stopwords Removal  \
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pas without much set next big bad ...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...
#
#                                           Lower Case  \
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pas without much set next big bad ...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...
#
#                                       After Stemming  \
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pa without much set next big bad m...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...
#
#                                  After Lemmatization  \
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pa without much set next big bad m...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...
#
#                                         cleaned_text
# 0  huge fan first one almost big fan second one d...
# 1  entri phase pa without much set next big bad m...
# 2  well happen mcu run ga last mcu film lacklust ...
# 3  well ill start say wasnt bad movi wasnt great ...
# 4  enjoy watch quantumania mostli solid fairli en...

# %% [markdown]
# # Question 3 (15 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# Write code for each of the sub parts with proper comments.
# !pip install nltk
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# True

# %%
# !pip install nltk
import nltk
nltk.download('words')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
import spacy
import nltk
from nltk import pos_tag, ne_chunk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tree import Tree
from collections import Counter
import pandas as pd

# Load the spaCy English model for dependency parsing and named entity recognition.
nlp = spacy.load("en_core_web_sm")

# Function to print constituency parsing tree using NLTK.
def print_constituency_tree(text):
    sentences = nltk.sent_tokenize(text)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        tagged = pos_tag(words)
        chunked = ne_chunk(tagged)
        for subtree in chunked:
            if type(subtree) == Tree:
                print(subtree.label(), " ".join(word for word, pos in subtree.leaves()))
            else:
                print(subtree[0], subtree[1])

# Function to print dependency parsing tree using spaCy.
def print_dependency_tree(text):
    doc = nlp(text)
    for token in doc:
        print(token.text, token.dep_, token.head.text, [child for child in token.children])

# Function to extract named entities and count their occurrences.
def extract_named_entities(text):
    doc = nlp(text)
    entity_counter = Counter()
    for ent in doc.ents:
        entity_counter[ent.label_] += 1
    return entity_counter

# Read only the first 100 rows from the CSV file to avoid run time issues
df = pd.read_csv('Antman_reviews_cleaned.csv', nrows=100)

# Combine the 'cleaned_text' column values into a single text
text = ' '.join(df['cleaned_text'].astype(str))


# (1) Parts of Speech (POS) Tagging
tokens = word_tokenize(text)
pos_tags = pos_tag(tokens)

# Count the number of nouns, verbs, adjectives, and adverbs in the text.
noun_count = len([word for word, pos in pos_tags if pos.startswith('N')])
verb_count = len([word for word, pos in pos_tags if pos.startswith('V')])
adj_count = len([word for word, pos in pos_tags if pos.startswith('J')])
adv_count = len([word for word, pos in pos_tags if pos.startswith('R')])

print(f"Total Nouns: {noun_count}")
print(f"Total Verbs: {verb_count}")
print(f"Total Adjectives: {adj_count}")
print(f"Total Adverbs: {adv_count}")

# (2) Constituency Parsing and Dependency Parsing
print("Constituency Parsing Trees:")
print_constituency_tree(text)
print("\nDependency Parsing Tree:")
print_dependency_tree(text)

# (3) Named Entity Recognition
entity_counter = extract_named_entities(text)
print("Named Entities:")
for entity, count in entity_counter.items():
    print(f"{entity}: {count}")
# Out:
# Streaming output truncated to the last 5000 lines.
# edit compound time []
# time nsubj use [cgi, rough, place, edit]
# could aux use []
# use conj m [time, could, develop, marvel]
# extra amod month []
# month npadvmod develop [extra]
# develop xcomp use [month, modok]
# modok dobj develop []
# atroci advmod marvel []
# executionthat det marvel []
# marvel advcl use [atroci, executionthat]
# late amod quantiti []
# quantiti nsubj say [late, thing]
# qualiti nmod thing []
# unfortunatelyanoth amod thing []
# thing appos quantiti [qualiti, unfortunatelyanoth]
# say ROOT say [quantiti, wish]
# wish xcomp say [take, come, was]
# marvel compound movi []
# movi nsubj take [marvel]
# would aux take []
# take ccomp wish [movi, would, humor, get]
# seriou compound humor []
# humor dobj take [seriou]
# get conj take [watch]
# repetit compound enjoy []
# enjoy nsubj watch [repetit]
# watch ccomp get [enjoy, feel]
# quantumania compound mcu []
# mostli nmod mcu []
# solid amod movi []
# fairli compound movi []
# entertain compound movi []
# movi compound mcu [solid, fairli, entertain]
# rel compound mcu []
# mcu compound underwhelm [quantumania, mostli, movi, rel]
# standard compound bit []
# bit compound underwhelm [standard]
# underwhelm nsubj feel [mcu, bit]
# feel ccomp watch [underwhelm, like]
# like prep feel []
# throwaway compound movi []
# movi compound keep [throwaway]
# someth compound memor []
# memor compound keep [someth]
# keep nsubj come [movi, memor]
# come ccomp wish [keep, back]
# back advmod come []
# tomi npadvmod biggest []
# biggest amod issu [tomi]
# issu nsubj was [biggest]
# was ccomp wish [issu, nt, engag]
# nt neg was []
# fulli compound engag []
# engag attr was [fulli]
# least advmod first []
# first amod enjoy [least]
# half amod movi []
# movi compound enjoy [half]
# enjoy nsubjpass lock [first, movi]
# was auxpass lock []
# nt neg lock []
# lock amod level [enjoy, was, nt]
# stori compound unfocuss []
# unfocuss compound level [stori]
# villain compound preval []
# becom compound preval []
# preval compound movi [villain, becom]
# movi compound level [preval]
# jump compound level []
# level nsubj complet [lock, unfocuss, movi, jump]
# does aux complet []
# nt neg complet []
# complet nsubj result [level, does, nt, make, did, like, get, overdo, thi, seem]
# make xcomp complet []
# much advmod weaker []
# weaker amod creativ [much]
# first amod creativ []
# halfth amod thing []
# thing compound creativ [halfth]
# surpri compound creativ []
# mesmer nmod creativ []
# visual amod creativ []
# creativ nsubj notic [weaker, first, thing, surpri, mesmer, visual]
# did aux notic []
# nt neg notic []
# notic amod cgi [creativ, did, nt]
# poor amod cgi []
# cgi nsubj like [notic, poor]
# like intj did [cgi]
# did conj complet [like, nt, wow]
# nt neg did []
# wow intj did []
# like intj complet [mayb]
# frequent amod mayb []
# mayb pobj like [frequent]
# get xcomp complet [movi]
# spoil nmod movi []
# visual amod movi []
# movi dobj get [spoil, visual, like]
# like prep movi [strang, avatar]
# doctor nsubj strang []
# strang pobj like [doctor]
# recent amod avatar []
# avatar pobj like [recent]
# still advmod good []
# lot npadvmod good []
# good amod funni [still, lot]
# pretti compound funni []
# funni nsubj overdo [good, pretti]
# does aux overdo []
# nt neg overdo []
# overdo ccomp complet [funni, does, nt]
# thi xcomp complet []
# second amod mcu []
# movi compound mcu []
# row compound mcu []
# mcu nsubj seem [second, movi, row]
# seem ccomp complet [mcu]
# dial nmod joke [back]
# back advmod dial []
# insert amod joke []
# joke compound probabl [dial, insert, strategi]
# strategi appos joke []
# probabl nsubj result [joke]
# result nsubj love [complet, probabl]
# neg amod reaction []
# reaction compound thor [neg]
# cartoonish compound thor []
# thor nsubj love [reaction, cartoonish]
# also advmod love []
# love ROOT love [result, thor, also, villain, say, crazi, watch, make, absolut]
# villain dobj love []
# wo aux say []
# nt neg say []
# say conj love [wo, nt, case]
# case dobj say []
# smart amod crazi []
# crazi dobj love [smart]
# like intj watch []
# do aux watch []
# nt neg watch []
# watch advcl love [like, do, nt, love]
# trailer compound love []
# damn advmod someon []
# awesomea compound someon []
# someon nsubj love [damn, awesomea]
# love dobj watch [trailer, someon, quantumania]
# almost advmod everyth []
# everyth nmod quantumania [almost]
# mcu compound quantumania []
# quantumania dobj love [everyth, mcu, near]
# near prep quantumania [rank]
# bottom compound mcu []
# mcu compound rank [bottom]
# rank pobj near [mcu]
# make dep love [come, shangchi, play]
# littl compound nervou []
# nervou nsubj come [littl]
# come ccomp make [nervou, phase]
# two nummod star []
# movi compound star []
# thor compound star []
# star compound phase [two, movi, thor]
# still advmod faith []
# faith nsubj join [still]
# join compound crowd [faith]
# mcu nmod gloom []
# doom compound gloom []
# gloom compound crowd [mcu, doom]
# crowd compound phase [join, gloom]
# phase advcl come [star, crowd, mcu]
# three nummod mcu []
# favorit npadvmod entri []
# entri amod mcu [favorit]
# entir amod mcu []
# mcu dobj phase [three, entri, entir]
# shangchi ccomp make [loki, dislik]
# loki dobj shangchi []
# way advmod home []
# home nsubj dislik [way]
# dislik ccomp shangchi [home]
# two nummod thor []
# etern amod thor []
# thor compound consist [two, etern]
# need compound consist []
# consist nsubj play [thor, need]
# also advmod play []
# play ccomp make [consist, also, view, open, thursday, imax, fallen, get]
# safe amod view []
# view dobj play [safe]
# open advcl play []
# thursday npadvmod play []
# imax dep play [realli]
# imax compound realli []
# marvel compound realli []
# realli dobj imax [imax, marvel]
# fallen dep play []
# ca aux get []
# nt neg get []
# get advcl play [ca, nt, thi]
# thi xcomp get []
# third amod charact []
# legaci compound charact []
# charact compound absolut [third, legaci]
# theyv compound absolut []
# absolut advcl love [charact, theyv]
# wast compound fact []
# fact compound strang [wast]
# doctor compound strang []
# strang compound antman [fact, doctor]
# thor compound antman []
# antman compound add [strang, thor]
# wast compound add []
# great amod add []
# establish amod cast []
# charact compound superb []
# superb compound cast [charact]
# cast compound add [establish, superb]
# add nsubj made [antman, wast, great, cast]
# made ROOT made [add, appear, add, yet, go, made, differ]
# kang nmod chump []
# main amod chump []
# villain compound chump []
# chump nsubj appear [kang, main, villain]
# appear ccomp made [chump, move]
# marvel compound plan []
# plan nsubj move [marvel]
# move ccomp appear [plan, forward]
# forward advmod move []
# kiang compound conqueror []
# conqueror compound movi [kiang]
# kang compound movi []
# chumpthi compound movi []
# movi nsubj add [conqueror, kang, chumpthi]
# add ccomp made [movi, poorli, endgam, end, quit, accept, univ, newlif, make]
# malai nmod poorli []
# poorli dative add [malai]
# written amod sinc []
# disappoint compound permeat []
# permeat compound sinc [disappoint]
# mcu compound sinc []
# sinc compound endgam [written, permeat, mcu]
# endgam dobj add [sinc, movi]
# one nummod movi []
# worst amod movi []
# third amod act []
# act compound movi [third]
# movi appos endgam [one, worst, act, modok]
# recent amod modok []
# histori compound modok []
# modok appos movi [recent, histori]
# use compound turn []
# dick compound turn []
# turn nmod thing [use, dick]
# could aux thing []
# dumbest amod thing []
# thing nsubj end [turn, could, dumbest, seen]
# i nsubj seen []
# ve aux seen []
# ever advmod seen []
# seen relcl thing [i, ve, ever, spoiler]
# even advmod spoiler []
# spoiler dobj seen [even]
# also advmod end []
# end ccomp add [thing, also, ran]
# movi nsubj ran []
# ran ccomp end [movi]
# budget compound absolut []
# absolut compound visual [budget]
# wast compound visual []
# visual nsubj quit [absolut, wast]
# quit ccomp add [visual, origin, without]
# stun compound delight []
# delight compound origin [stun]
# creativ compound shape []
# design compound shape []
# shape compound form [creativ, design]
# form compound origin [shape]
# storylin compound origin []
# le compound origin []
# origin dobj quit [delight, form, storylin, le]
# without prep quit [way]
# much amod way []
# way pobj without [much]
# intellectu amod depth []
# emot nmod depth []
# ethic amod depth []
# depth nmod movi [intellectu, emot, ethic]
# recent amod movi []
# marvel compound movi []
# movi nsubj appar [depth, recent, marvel]
# appar compound focu [movi]
# movi compound focu []
# focu nsubj accept [appar, movi]
# accept conj add [focu, lose]
# broad amod audienc []
# audienc compound quantumania [broad]
# rang compound quantumania []
# includ compound quantumania []
# young amod quantumania []
# peopl compound quantumania []
# quantumania nsubj lose [audienc, rang, includ, young, peopl]
# lose ccomp accept [quantumania, creat, quantum]
# sharp amod creat []
# refresh amod creat []
# focu compound creat []
# creat dobj lose [sharp, refresh, focu]
# live amod quantum []
# entiti compound quantum []
# quantum dobj lose [live, entiti]
# univ advcl add [reflect]
# anthropomorph det child []
# humanba compound perhap []
# perhap compound relat [humanba]
# relat compound child [perhap]
# child nsubj reflect [anthropomorph, relat]
# reflect relcl univ [child, life]
# diver compound origin []
# origin compound form [diver]
# form compound life [origin]
# life dobj reflect [form]
# newlif advcl add []
# would aux realli []
# realli nsubj make [would]
# make ccomp add [realli, make]
# film nsubj stellar []
# stellar amod effect [film]
# even advmod effect []
# special amod effect []
# set amod effect []
# design nmod effect []
# special amod effect []
# effect nsubj make [stellar, even, special, set, design, special]
# make ccomp make [effect, room, end]
# gorgeou nsubj set []
# set nsubj room [gorgeou]
# still advmod room []
# room ccomp make [set, still]
# crisp amod background []
# detail compound background []
# immer compound background []
# design compound work []
# work compound background [design]
# background nsubj end [crisp, detail, immer, work]
# end ccomp make [background, expect]
# mere amod project []
# basic amod project []
# anim compound project []
# project nsubj expect [mere, basic, anim, level]
# come compound level []
# level appos project [come]
# expect ccomp end [project, provid]
# contemporari compound product []
# marvel compound product []
# product compound provid [contemporari, marvel]
# ye compound movi []
# movi compound provid [ye]
# provid ccomp expect [product, movi, amaz]
# amaz prep provid [canva]
# backdrop compound canva []
# canva pobj amaz [backdrop]
# yet cc made []
# substanc compound movi []
# plot compound movi []
# movi compound level [substanc, plot]
# rise compound level []
# level nmod lot [movi, rise]
# one nummod end []
# end nmod lot [one]
# movi compound lot []
# lot nsubj flash [level, end, movi]
# flash nsubj bite [lot]
# le compound satisfactori []
# satisfactori nsubj bite [le]
# bite nsubj repeat [flash, satisfactori]
# new amod antman []
# antman nmod movi [new]
# bad amod movi []
# movi nsubj repeat [antman, bad]
# repeat nsubj go [bite, movi, excu]
# current amod trend []
# trend nmod product [current]
# plagu nmod product []
# new amod product []
# marvel compound product []
# product nmod charact [trend, plagu, new, marvel]
# main amod charact []
# charact nsubj excu [product, main]
# excu ccomp repeat [charact, definit]
# introduc amod definit []
# new amod charact []
# charact compound definit [new]
# definit dobj excu [introduc, charact]
# go ccomp made [repeat, stori, make, lack, set, know]
# stori dobj go []
# make advcl go [feel]
# paul compound import []
# rudd compound import []
# charact nmod import []
# le nmod import []
# import nsubj feel [paul, rudd, charact, le]
# do aux feel []
# nt neg feel []
# feel ccomp make [import, do, nt, stori, good, feel]
# stori compound stori []
# stori dobj feel [stori]
# even advmod good []
# good advmod feel [even]
# feel ccomp feel []
# lack advcl go []
# great amod movi []
# charact compound previou []
# previou compound movi [charact]
# movi nsubj set [great, previou]
# set conj go [movi, stori]
# tone compound stori []
# stori dobj set [tone]
# do aux know []
# nt neg know []
# even advmod know []
# know conj go [do, nt, even, made]
# happen amod movi []
# previou compound movi []
# movi nmod person [happen, previou]
# hard compound believ []
# believ compound director [hard]
# director compound person [believ]
# person nsubj made [movi, director]
# made ccomp know [person]
# two nummod definit []
# prior amod definit []
# movi compound ad []
# ad compound kang [movi]
# kang compound definit [ad]
# definit nsubj made [two, prior, kang]
# made ccomp made [definit, push]
# kang compound movi []
# movi compound sum [kang]
# antman compound line []
# liter compound line []
# line compound sum [antman, liter]
# film compound sum []
# sum compound covid [movi, line, film]
# mcu compound covid []
# becom compound covid []
# sinc compound covid []
# covid nsubj hit [sum, mcu, becom, sinc]
# hit nsubj hope [covid, hope]
# world compound disney []
# disney compound lang [world]
# jump compound shark []
# shark compound lang [jump]
# film compound lang []
# universescott compound lang []
# lang compound hope [disney, shark, film, universescott]
# hope ccomp hit [lang, return]
# van compound dyne []
# dyne nsubj return [van]
# return ccomp hope [dyne, togeth]
# continu compound antman []
# adventur compound antman []
# antman compound togeth [continu, adventur]
# wasp compound togeth []
# togeth npadvmod return [antman, wasp]
# hope nsubj strang [hit, find]
# parent compound famili []
# janet compound famili []
# hank compound famili []
# pym compound famili []
# scott compound famili []
# daughter compound famili []
# cassi compound lang []
# lang compound famili [cassi]
# famili nsubj find [parent, janet, hank, pym, scott, daughter, lang]
# find ccomp hope [famili]
# explor compound pretti []
# pretti compound quantum [explor]
# redund compound quantum []
# quantum compound interact [pretti, redund]
# realm compound interact []
# interact nsubj strang [quantum, realm]
# strang compound adventur [hope, interact]
# new amod embark []
# cgi compound creatur []
# creatur compound embark [cgi]
# monstro compound embark []
# embark compound adventur [new, creatur, monstro]
# adventur nsubj push [strang, embark]
# push ccomp made [adventur, beyond, thought]
# beyond prep push []
# limit compound boredom []
# boredom compound thought [limit]
# thought advcl push [boredom, antman]
# possiblei compound antman []
# love compound antman []
# antman dobj thought [possiblei, love]
# first amod film []
# two nummod film []
# film nsubj differ [first, two]
# differ ccomp made [film, rudd]
# anyth compound relea []
# marvel compound relea []
# relea compound rudd [anyth, marvel]
# paul compound rudd []
# rudd dobj differ [relea, paul]
# amaz advmod hero []
# titular amod hero []
# hero compound marvel [amaz, titular]
# humour compound marvel []
# marvel compound childish [hero, humour]
# humour compound childish []
# childish nsubj dare [marvel, humour, better]
# better advmod childish []
# dare aux differ [childish]
# differ ROOT differ [dare, payoff, given, watch, make]
# payoff dobj differ []
# someth amod debacl [fresh]
# fresh amod someth []
# even advmod marvel []
# marvel amod debacl [even]
# behemoth compound tire []
# becom compound tire []
# littl compound tire []
# tire compound debacl [behemoth, becom, littl]
# especi compound debacl []
# debacl compound wright [someth, marvel, tire, especi]
# age compound wright []
# ultron compound wright []
# wright nsubjpass given [debacl, age, ultron]
# was auxpass given []
# nt neg given []
# given ccomp differ [wright, was, nt, shoulder]
# cold amod shoulder []
# shoulder dobj given [cold]
# could aux watch []
# watch conj differ [could, think]
# someth amod differ []
# differ nsubj think [someth]
# do aux think []
# nt neg think []
# think ccomp watch [differ, do, nt, panach]
# blame compound place []
# place compound studio [blame]
# reed compound studio []
# shoulder compound studio []
# studio compound final [place, reed, shoulder]
# final nsubj say [studio]
# say nsubj panach [final]
# does aux panach []
# nt neg panach []
# panach ccomp think [say, does, nt, meld, taken]
# first amod bore []
# film compound hadit []
# hadit compound bore [film]
# bore nmod effect [first, hadit]
# dull amod effect []
# effect nsubj meld [bore, dull]
# meld ccomp panach [effect, one]
# one dobj meld [like]
# like prep one [maker]
# maker pobj like []
# taken conj panach []
# cantina compound scene []
# scene compound decid [cantina]
# new compound hope []
# hope compound decid [new]
# decid nsubj make [scene, hope]
# make conj differ [decid, surround, seem]
# whole amod movi []
# movi nsubj surround [whole]
# surround ccomp make [movi]
# ad compound suppo []
# suppo nmod major [ad]
# bigger amod major []
# adversari compound major []
# thao compound kang []
# kang compound major [thao]
# villain compound major []
# major nsubj seem [suppo, bigger, adversari, kang, villain]
# seem ccomp make [major, tell, make]
# home compound campest []
# campest compound bodi [home]
# bone compound bodi []
# bodi compound noth [campest, bone]
# noth compound charact [bodi]
# remot compound sinist []
# sinist compound charact [remot]
# charact nsubj tell [noth, sinist]
# tell ccomp seem [charact, shut]
# peopl compound shut []
# shut dobj tell [peopl]
# make advcl seem [add]
# costum compound tighter []
# slightli compound tighter []
# tighter nsubj add [costum, slightli]
# add ccomp make [tighter, murray]
# worthless amod murray []
# cameo compound murray []
# murray dobj add [worthless, cameo]
# earth compound k []
# k dep lay [earth]
# marvel compound film []
# film nsubj lay [marvel]
# lay ROOT lay [k, film, mcu, pfeiffer, happen, end, tell, read, wear, shame]
# bowel compound mcu []
# mcu dobj lay [bowel, along]
# along prep mcu []
# etern amod thunder []
# love compound thunder []
# thunder compound pfeiffer [etern, love]
# dark amod pfeiffer []
# worlddougla compound pfeiffer []
# pfeiffer npadvmod lay [thunder, dark, worlddougla, wast]
# unforgiv compound wast []
# wast appos pfeiffer [unforgiv]
# dougla compound someth []
# someth nsubj happen [dougla]
# happen conj lay [someth]
# end dobj lay []
# ant compound pfeieffer []
# pfeieffer nsubj tell [ant]
# tell conj lay [pfeieffer, stori, offer]
# stori dobj tell []
# kang compound support []
# littl compound support []
# support nsubj offer [kang, littl]
# offer ccomp tell [support, guy]
# asid compound guy []
# guy dobj offer [asid]
# read advcl lay [mind]
# mind dobj read []
# one nummod joke []
# run compound joke []
# joke nsubj wear [one, run]
# wear conj lay [joke, wannab, thi, becom]
# realli compound wannab []
# thin compound valkyri []
# valkyri compound wannab [thin]
# wannab dobj wear [realli, valkyri]
# thi dative wear [want]
# franchi compound mcu []
# mcu nsubj want [franchi]
# want ccomp thi [mcu, succeed]
# succeed xcomp want []
# rudd nmod role []
# brilliant compound funni []
# funni compound role [brilliant]
# role compound becom [rudd, funni]
# one nummod hero []
# dimens compound hero []
# hero compound becom [one, dimens]
# multipli compound becom []
# becom conj wear [role, hero, multipli]
# even advmod himselfit []
# unfunni compound version []
# version compound himselfit [unfunni]
# himselfit nmod shame [even, version]
# real amod shame []
# shame compound shame [himselfit, real]
# realli compound shame []
# shame nsubj lay [shame, realli]
# hey intj is []
# mcu compound touch []
# taika compound touch []
# touch compound realli [mcu, taika]
# realli nsubj is [touch]
# is ccomp expect [hey, realli, nt, realli]
# nt neg is []
# goodi compound realli []
# realli attr is [goodi]
# low nsubj expect []
# expect ROOT expect [is, low, go, execut]
# rest compound phase []
# phase nsubj go [rest]
# thi aux go []
# go ccomp expect [phase, thi, univ]
# foreverhelp nmod wasp [antman]
# u compound antman []
# antman dobj foreverhelp [u]
# wasp compound cinemat [foreverhelp]
# quantumania nmod cinemat []
# first amod phase []
# film compound phase []
# phase compound marvel [first, film]
# marvel compound cinemat [phase]
# cinemat nsubj univ [wasp, quantumania, marvel]
# univ ccomp go [cinemat]
# onc nmod star []
# direct amod star []
# peyton compound star []
# reed compound star []
# star compound rudd [onc, direct, peyton, reed]
# paul compound rudd []
# rudd compound titl [star, paul]
# evangelin compound titl []
# lilli compound titl []
# titl compound role [rudd, evangelin, lilli]
# role compound rank [titl]
# rank nsubj execut [role, among]
# among prep rank [effort]
# mcu nmod effort []
# weakest amod effort []
# effort pobj among [mcu, weakest]
# execut ccomp expect [rank, aveng]
# fun compound emot []
# emot compound time [fun]
# payoffssom compound time []
# time compound aveng [emot, payoffssom]
# event compound aveng []
# aveng dobj execut [time, event]
# endgam compound rudd []
# scott compound lang []
# lang compound rudd [scott]
# paul compound rudd []
# rudd compound spotlight [endgam, lang, paul]
# enjoy compound spotlight []
# spotlight nsubj suck [rudd, enjoy]
# recent amod hope []
# public amod autobiographi []
# autobiographi amod hope [public]
# scott compound hang []
# hang compound hope [scott]
# hope compound pfieffer [recent, autobiographi, hang]
# van compound dyne []
# dyne compound parent [van]
# evangelin compound parent []
# lilli compound parent []
# parent compound michael [dyne, evangelin, lilli]
# hank compound michael []
# michael compound janet [parent, hank]
# dougla compound janet []
# janet compound michel [michael, dougla]
# michel compound pfieffer [janet]
# pfieffer compound group [hope, michel]
# scott compound daughter []
# daughter compound group [scott]
# cassi compound group []
# kathryn compound group []
# newton compound group []
# group compound accid [pfieffer, daughter, cassi, kathryn, newton]
# accid nsubj suck [group]
# suck ROOT suck [spotlight, accid, quantum, thought, seem]
# quantum dobj suck []
# realm compound initi []
# discov compound destitut []
# destitut compound initi [discov]
# initi nsubj thought [realm, destitut]
# thought ccomp suck [initi, learn]
# soon amod group []
# group nsubj learn [soon]
# learn ccomp thought [group, stop, make]
# danger nmod realm []
# new amod realm []
# threat compound inhabit []
# inhabit compound realm [threat]
# realm npadvmod stop [danger, new, inhabit]
# known amod major []
# kang compound conqueror []
# conqueror compound major [kang]
# jonathan compound major []
# major nsubj stop [known, conqueror, jonathan]
# stop ccomp learn [realm, major, place]
# noth nmod place []
# escap amod place []
# fate compound place []
# prison compound place []
# place dobj stop [noth, escap, fate, prison]
# kang nsubj make []
# make ccomp learn [kang, stop]
# posit nsubj scott []
# clear amod scott []
# scott nsubj stop [posit, clear]
# stop ccomp make [scott, irrev]
# kang nsubj irrev []
# irrev ccomp stop [kang]
# damag amod timeright []
# inflict amod timeright []
# space compound timeright []
# timeright nsubj seem [damag, inflict, space]
# seem conj suck [timeright, aveng]
# mcu compound strang []
# strang compound aveng [mcu]
# hold compound pattern []
# pattern compound aveng [hold]
# aveng oprd seem [strang, pattern]
# endgam npadvmod expect []
# although mark made []
# sever amod show []
# film compound show []
# tv compound show []
# show nsubj made [sever, film, tv]
# made advcl expect [although, show]
# sinc nsubj has []
# has aux expect [sinc, nt]
# nt neg has []
# realli compound indic []
# concret compound indic []
# indic nsubj expect [realli, concret]
# expect ccomp thought [endgam, made, has, indic, thi, establish, previou, contain, dramat]
# seri amod head []
# head nsubj thi [seri]
# thi ccomp expect [head, year]
# even advmod year []
# year npadvmod thi [even]
# have aux take [nt, villain]
# nt neg have []
# proper amod villain []
# buildup nmod villain []
# main amod villain []
# villain dobj have [proper, buildup, main]
# take nsubj establish [have, antman, quantumania]
# thano compound antman []
# antman dobj take [thano]
# wasp compound quantumania []
# quantumania dobj take [wasp]
# least advmod establish []
# establish ccomp expect [take, least, thing, look]
# thing dobj establish []
# look dep establish [forward, futur]
# forward advmod look []
# futur npadvmod look []
# never neg way []
# way npadvmod distinguish [never]
# distinguish amod surpri [way]
# noth compound rel []
# rel nmod alreadi [noth]
# mediocr npadvmod entri []
# entri amod alreadi [mediocr]
# alreadi compound surpri [rel, entri]
# expan compound surpri []
# cinemat amod phase []
# universegiven amod suppo []
# film compound suppo []
# suppo compound phase [universegiven, film]
# kick compound phase []
# phase compound surpri [cinemat, suppo, kick]
# surpri nsubj excit [distinguish, alreadi, expan, phase]
# excit nsubj previou [surpri, moment]
# moment npadvmod excit []
# hype compound audienc []
# audienc nsubj previou [hype]
# previou ccomp expect [excit, audienc, film]
# two nummod film []
# antman compound film []
# film dobj previou [two, antman]
# contain ccomp expect [fan, come, yet, find]
# funniest compound fan []
# entertain compound scene []
# scene compound fan [entertain]
# fan dobj contain [funniest, scene]
# like intj come []
# come advcl contain [like, appreci, year]
# appreci dep come []
# mcu compound year []
# year npadvmod come [mcu]
# yet cc contain []
# struggl compound find []
# find conj contain [struggl, leav]
# anyth compound enjoy []
# remot compound enjoy []
# enjoy nsubj leav [anyth, remot]
# could aux leav []
# leav ccomp find [enjoy, could, impress]
# impress advcl leav [banter]
# viewer amod asid []
# asid nmod banter [viewer]
# odd amod banter []
# dri compound banter []
# banter dobj impress [asid, odd, dri]
# scott nmod scene []
# amu nmod scene []
# scene nmod sever [scott, amu, relief]
# comic amod relief []
# relief appos scene [comic]
# allevi compound sever []
# sever compound humor [scene, allevi]
# whenev compound strike []
# someth amod bad []
# bad amod place [someth]
# taken amod place []
# place compound mcu [bad, taken]
# mcu compound film [place]
# film compound strike [mcu]
# abl compound strike []
# strike compound balanc [whenev, film, abl]
# balanc compound humor [strike]
# humor nsubj dramat [sever, balanc]
# dramat ccomp expect [humor]
# one nummod time []
# lean amod time []
# heavili nmod tone []
# dark compound tone []
# tone compound fun [heavili, dark]
# simpli compound fun []
# fun compound watch [tone, simpli]
# watch compound time [fun]
# time npadvmod gone [one, lean, watch, want]
# filmmak nsubj want []
# want relcl time [filmmak, make]
# make xcomp want []
# darker amod way [film]
# antman compound film []
# film nsubj darker [antman]
# fine amod way []
# way nsubj gone [darker, fine]
# gone csubj imagin [time, way, cgi, make]
# itanoth amod cgi []
# big amod problem []
# problem compound film [big]
# film compound goe [problem]
# goe compound cgi [film]
# way nmod overu []
# far advmod overu []
# overu amod cgi [way, far]
# cgi attr gone [itanoth, goe, overu]
# though mark use []
# mcu nsubj use []
# use advcl make [though, mcu, film]
# plenti nmod film []
# cgi nmod film []
# prior amod film []
# film dobj use [plenti, cgi, prior]
# least advmod tri []
# tri nsubj make [least]
# make advcl gone [use, tri, give]
# look nsubj give [like]
# like prep look [realiti]
# basi compound realiti []
# realiti pobj like [basi]
# give ccomp make [look, screen]
# audienc amod screen []
# impress compound screen []
# screen dobj give [audienc, impress]
# could aux imagin []
# imagin ccomp thought [gone, could, physic, use, feel, assum, match]
# physic dobj imagin []
# right amod charact []
# front amod charact []
# charact nsubj use [right, front]
# use conj imagin [charact, film, look]
# much amod mean []
# mean amod end [much]
# end nmod film [mean]
# whole amod film []
# film dobj use [end, whole]
# look xcomp use []
# realist amod prequel []
# star compound war []
# war compound prequel [star]
# prequel compound point [realist, war]
# point compound quantum [prequel]
# quantum compound realm [point]
# realm nsubj feel [quantum]
# ever advmod feel []
# feel conj imagin [realm, ever, like, watch]
# like prep feel [creatur]
# real amod place []
# place compound inhabit [real]
# inhabit compound popul [place]
# popul compound creatur [inhabit]
# variou compound creatur []
# creatur pobj like [popul, variou]
# instead advmod watch []
# constantli nsubj watch []
# watch advcl feel [instead, constantli, move]
# actor nsubj move []
# move ccomp watch [actor, around, within]
# around advmod move []
# within prep move [confin]
# limit compound confin []
# confin pobj within [limit]
# assum conj imagin [way]
# green compound screen []
# screen compound stage [green]
# stage compound way [screen]
# way npadvmod assum [stage]
# look compound plan []
# plan nsubj match [look]
# does aux match []
# nt neg match []
# match advcl imagin [plan, does, nt, project, look]
# vibrant amod project []
# environ amod project []
# project dobj match [vibrant, environ]
# everyth nsubj look []
# look conj match [everyth, steril]
# clean amod steril []
# steril npadvmod look [clean, near]
# near prep steril []
# imposs nmod charact []
# imagin compound charact []
# charact nmod locat [imposs, imagin]
# actual amod locat []
# locat nsubj thought [charact, actual]
# first advmod thought []
# thought ROOT thought [expect, imagin, locat, first, kept, view, thanoss, was, pretti, use, hope, say, look, inflict, differ, guess, see, point, relea, leav, impress, told]
# mayb compound desens []
# becom compound desens []
# desens compound effect [mayb, becom]
# cgi compound gener []
# gener nmod effect [cgi]
# visual amod effect []
# effect nsubj kept [desens, gener, visual]
# kept ccomp thought [effect, pile, found]
# pile dobj kept []
# found oprd kept [happen]
# becom compound stori []
# le nmod stori []
# le advmod invest []
# invest compound stori [le]
# stori nsubj happen [becom, le, invest]
# never neg happen []
# happen ccomp found [stori, never]
# mcu npadvmod entri []
# entri amod nowth [mcu]
# nowth nmod doubt [entri, cast]
# cast acl nowth []
# film nmod doubt []
# fine amod doubt []
# consid amod work []
# work compound doubt [consid]
# doubt nsubj view [nowth, film, fine, work]
# view ccomp thought [doubt, exud, especi]
# best amod rudd []
# paul compound rudd []
# rudd nsubj exud [best, paul]
# still advmod exud []
# exud ccomp view [rudd, still, treat]
# likeabl compound charm []
# charm compound langantman [likeabl]
# scott compound langantman []
# langantman compound treat [charm, scott]
# treat dobj exud [langantman, like]
# like prep treat [ill]
# true amod hero []
# hero compound ill [true]
# gener nmod ill []
# public compound ill []
# ill pobj like [hero, gener, public]
# admit nmod underdog []
# nice amod underdog []
# see compound underdog []
# underdog nsubj especi [admit, nice, see, like]
# like prep underdog [final]
# scott compound final []
# final pobj like [scott]
# get compound time []
# recognit compound deserv []
# deserv compound time [recognit]
# time npadvmod especi [get, deserv]
# especi ccomp view [underdog, time, consid, part, play]
# consid advmod especi []
# import compound part []
# part dobj especi [import]
# play xcomp especi [bring]
# help compound aveng []
# aveng nsubj bring [help]
# bring ccomp play [aveng, back, popul]
# back advmod bring []
# half nummod popul []
# univ amod popul []
# popul dobj bring [half, univ]
# thanoss prep thought [action]
# action pobj thanoss []
# scott nsubj play [scene]
# best amod scene []
# scene npadvmod scott [best]
# daughter compound newton []
# cassi compound newton []
# kathryn compound newton []
# newton nsubj play [daughter, cassi, kathryn]
# play compound first [scott, newton, place, fuhrmann]
# role compound place []
# place dobj play [role]
# emma compound fuhrmann []
# fuhrmann dobj play [emma]
# first nsubj was [play]
# was ccomp thought [first, nt, sure]
# nt neg was []
# sure acomp was [prove]
# recast compound charact []
# charact compound newton [recast]
# newton nsubj prove [charact]
# prove ccomp sure [newton, seem]
# right amod part []
# part compound charact [right]
# physic amod requir []
# requir compound charact [physic]
# charact nsubj seem [part, requir]
# seem ccomp prove [charact, come]
# come xcomp seem []
# natur compound newton []
# newton nsubj pretti [natur]
# also advmod pretti []
# pretti ccomp thought [newton, also, underwhelm]
# good amod underwhelm []
# chemistri amod fatheri []
# rudd amod fatheri []
# onscreen compound fatheri []
# fatheri amod underwhelm [chemistri, rudd, onscreen]
# somewhat advmod underwhelm []
# underwhelm dobj pretti [good, fatheri, somewhat]
# evangelin compound lilli []
# lilli compound michel [evangelin]
# michel compound pfeiffer [lilli]
# pfeiffer compound michael [michel]
# michael nsubj use [pfeiffer]
# dougla nsubj use []
# use ccomp thought [michael, dougla, time, around, see]
# time dobj use []
# around prep use []
# film compound antman []
# antman compound titl [film]
# wasp compound titl []
# titl compound realli [antman, wasp]
# do aux realli []
# nt neg realli []
# realli nsubj see [titl, do, nt]
# see xcomp use [realli, togeth]
# enough amod togeth []
# titular amod thing []
# charact compound thing []
# thing compound togeth [titular, charact]
# togeth dobj see [enough, thing]
# instead advmod hope []
# hope advcl thought [instead, hang, seem, contribut, were]
# mainli nsubj hang []
# hang ccomp hope [mainli, around, provid]
# around prep hang []
# parent compound provid []
# provid npadvmod hang [parent, scene]
# decent nmod scene []
# scene appos provid [decent]
# three nummod togeth []
# bond compound togeth []
# togeth nsubj seem [three, bond]
# still advmod seem []
# seem ccomp hope [togeth, still, keep]
# like mark keep []
# strang compound deci []
# creativ compound deci []
# deci nsubj keep [strang, creativ]
# keep advcl seem [like, deci, separ, go]
# separ dobj keep []
# scott nmod addit []
# long amod addit []
# addit compound pfeiffer [scott, long]
# dougla compound pfeiffer []
# pfeiffer compound exactli [addit, dougla]
# exactli nsubj go [pfeiffer]
# go xcomp keep [exactli, wast]
# wast npadvmod go []
# did aux contribut []
# nt neg contribut []
# contribut ccomp hope [did, nt, hope]
# much amod hope []
# stori compound hope []
# hope dobj contribut [much, stori]
# were ccomp hope [nt, scene]
# nt neg were []
# one nummod scene []
# crucial amod scene []
# scene attr were [one, crucial, near]
# near prep scene [end]
# end pobj near []
# i compound d []
# d nsubj say [i]
# say ccomp thought [d, quit, stood]
# hank compound film []
# janet compound film []
# presenc compound film []
# film nsubj quit [hank, janet, presenc]
# quit ccomp say [film, time]
# forgett compound time []
# time dobj quit [forgett, kept]
# kept acl time [care, happen, meantimehowev]
# forget compound care []
# care dobj kept [forget]
# happen oprd kept [cassi]
# scott compound cassi []
# cassi dobj happen [scott]
# meantimehowev oprd kept []
# one nummod charact []
# charact nsubj stood [one]
# stood ccomp say [charact, play, watch]
# kang compound conqueror []
# conqueror nsubj play [kang]
# play ccomp stood [conqueror]
# surprisingli compound anybodi []
# intimid compound anybodi []
# jonathan compound anybodi []
# major compound anybodi []
# anybodi nsubj watch [surprisingli, intimid, jonathan, major]
# watch ccomp stood [anybodi, remain]
# first amod season []
# season npadvmod seri [first]
# disney compound seri []
# seri compound charact [season, disney]
# loki nmod charact []
# rememb amod charact []
# charact nsubj remain [seri, loki, rememb, known]
# known acl charact [back]
# back advmod known []
# remain ccomp watch [charact, thi, get]
# thi prep remain [time]
# time pobj thi []
# get advcl remain [better]
# better acomp get []
# look ccomp thought [determin]
# kang compound determin []
# motiv compound determin []
# villain compound determin []
# determin attr look [kang, motiv, villain]
# inflict ccomp thought []
# chao nsubj differ []
# differ ccomp thought [chao, person]
# multiv nmod conceal []
# major amod conceal []
# good amod conceal []
# job compound conceal []
# conceal compound kang [multiv, major, good, job]
# kang nmod person [conceal]
# true amod person []
# person dobj differ [kang, true, use]
# whose poss vulner []
# vulner nsubj use [whose]
# use relcl person [vulner, intent]
# facad compound malici []
# malici compound intent [facad]
# intent dobj use [malici]
# guess conj thought [watch, stop]
# like intj watch []
# watch xcomp guess [like, charact]
# kang nsubj charact []
# charact ccomp watch [kang, film]
# film npadvmod charact []
# kind compound goal []
# interest compound end []
# end compound goal [interest]
# goal compound tri [kind, end]
# tri compound stop [goal]
# stop ccomp guess [tri, look]
# i nsubjpass look []
# m auxpass look []
# look ccomp stop [i, m, forward]
# forward advmod look []
# see ccomp thought [think]
# kang compound mcu []
# futur compound mcu []
# mcu compound project [kang, futur]
# project nsubj think [mcu]
# think ccomp see [project, threaten, reli, audienc, assumpt]
# potenti nsubj threaten []
# threaten ccomp think [potenti, thano, begin]
# thano dobj threaten []
# back amod sagafor []
# infin compound sagafor []
# sagafor nsubj begin [back, infin]
# begin ccomp threaten [sagafor, tri]
# new amod antman []
# chapter compound mcu []
# mcu compound antman [chapter]
# antman compound quantumania [new, mcu]
# wasp compound quantumania []
# quantumania nsubj land [antman, wasp]
# does aux land []
# nt neg land []
# land compound way [quantumania, does, nt]
# way compound film [land]
# previou compound film []
# film nsubj tri [way, previou]
# tri ccomp begin [film, entri]
# hard advmod darker []
# one nummod darker []
# darker npadvmod entri [hard, one]
# entri xcomp tri [darker, end]
# seri amod end []
# ant amod end []
# main amod end []
# villain compound end []
# end dobj entri [seri, ant, main, villain]
# reli advmod think []
# much advmod audienc []
# audienc ccomp think [much]
# assumpt prep think [detail]
# thing compound detail []
# address compound detail []
# detail pobj assumpt [thing, address]
# later advmod point []
# point npadvmod thought [later]
# hope compound vol []
# guardian compound vol []
# galaxi compound vol []
# vol nsubj relea [hope, guardian, galaxi]
# next amod mcu []
# film compound mcu []
# mcu npadvmod relea [next, film]
# relea ccomp thought [vol, mcu, schedul]
# schedul dobj relea []
# leav ccomp thought []
# better advmod impress []
# impress ccomp thought [better, work]
# long amod time []
# time compound fan [long]
# fan nsubj work [time]
# does aux work []
# nt neg work []
# work ccomp impress [fan, does, nt]
# rel nmod stori []
# dull amod phase []
# phase compound rate [dull]
# rate compound stori [phase]
# film compound stori []
# awfulth compound stori []
# stori compound hope [rel, rate, film, awfulth]
# ridicul compound waysfirstli []
# waysfirstli compound hope [ridicul]
# hope compound mother [stori, waysfirstli]
# mother compound realm [hope]
# quantum compound realm []
# realm nsubj told [mother, quantum]
# never neg told []
# told ccomp thought [realm, never, husband, entir, therefor, develop]
# husband dobj told []
# entir xcomp told [speci, stream]
# univ compound speci []
# speci dobj entir [univ]
# live amod stream []
# complex amod ant []
# environmentssecondli compound ant []
# ant compound quantum [complex, environmentssecondli]
# happen compound quantum []
# follow compound quantum []
# quantum compound stream [ant, happen, follow]
# univ amod stream []
# differ amod stream []
# stream dobj entir [live, quantum, univ, differ]
# therefor prep told [etern]
# etern pobj therefor []
# develop ccomp told []
# becom nmod intelligentthirdli []
# super compound intelligentthirdli []
# intelligentthirdli compound hell [becom, super]
# hell compound modox [intelligentthirdli]
# modox compound suddenli [hell]
# second amod rate []
# rate compound suddenli [second]
# charact compound suddenli []
# suddenli nsubj appear [modox, rate, charact]
# appear ROOT appear [suddenli, think, entir, watch, make, thank]
# quantum compound headfin []
# realm compound headfin []
# headfin nsubj think [quantum, realm, film]
# cgi nmod film []
# great amod excit []
# lose compound excit []
# excit compound film [great, lose]
# entir amod film []
# film appos headfin [cgi, excit, entir]
# think ccomp appear [headfin, watch]
# watch xcomp think []
# entir oprd appear [film]
# film compound film []
# film dobj entir [film]
# one nummod room []
# room nmod noth [one, screen]
# green compound screen []
# screen appos room [green]
# noth nsubj watch [room]
# reali nsubj watch []
# watch ccomp appear [noth, reali, bore, rewatch]
# film compound week []
# week compound batch [film]
# batch compound bore [week]
# minut compound bore []
# bore nsubj bore [batch, minut]
# never neg bore []
# bore ccomp watch [bore, never, film, watch]
# film dobj bore []
# watch ccomp bore [need]
# everyth compound boringhonestli []
# film compound boringhonestli []
# boringhonestli nsubj need [everyth, film]
# need dobj watch [boringhonestli, hit]
# mcu nsubj hit []
# hit ccomp need [mcu]
# rewatch advcl watch []
# one nummod world []
# aveng compound marvel []
# film compound marvel []
# likesth compound marvel []
# graphicsworld compound marvel []
# design compound marvel []
# marvel compound world [aveng, film, likesth, graphicsworld, design]
# realli nmod world []
# great amod world []
# budget compound creat []
# creat compound world [budget]
# world compound imagin [one, marvel, realli, great, creat]
# imagin compound continu [world]
# instal amod continu []
# continu nsubj make [imagin, instal]
# make ccomp appear [continu, make]
# happenlavish amod color []
# color compound world [happenlavish]
# odd amod beast []
# beast compound world [odd]
# world compound tri [color, beast]
# strang compound tri []
# world compound tri []
# tri nsubj make [world, strang, world]
# make ccomp make [tri, thought]
# thought ccomp make [build]
# layeringgreat amod cultur []
# cultur nmod book [layeringgreat]
# comic amod book []
# book nsubj build [cultur, comic, foundat]
# sen compound foundat []
# atmosph nmod foundat []
# new amod foundat []
# world compound lot []
# lot compound foundat [world]
# foundat appos book [sen, atmosph, new, lot]
# may aux build []
# build ccomp thought [book, may, futurefeel, like]
# futurefeel dobj build []
# like prep build [help]
# strong amod pinch []
# mash compound star []
# star compound war [mash]
# war compound marvel [star]
# marvel compound pinch [war]
# battlestar compound pinch []
# pinch compound movi [strong, marvel, battlestar]
# movi compound help [pinch]
# help pobj like [movi, spice]
# spice xcomp help [thing]
# thing dobj spice []
# well advmod nice []
# nice amod time [well]
# refer nmod time []
# indeedth nmod time []
# comedi amod time []
# time compound comedi [nice, refer, indeedth, comedi]
# comedi compound awesom [time]
# awesom nsubj thank [comedi]
# often advmod thank []
# thank advcl appear [awesom, often, write, come]
# write xcomp thank [rudd]
# paul compound rudd []
# rudd dobj write [paul]
# make compound line []
# line nsubj come [make]
# come ccomp thank [line, make]
# lifeth amod work []
# snarki compound humor []
# humor compound sarcasm [snarki]
# sarcasm compound work [humor]
# work nsubj make [lifeth, sarcasm]
# well intj make []
# truli compound antman []
# laugh compound antman []
# bunch compound antman []
# antman nsubj make [truli, laugh, bunch]
# make advcl come [work, well, antman, time, add]
# work compound level []
# level compound funther [work]
# funther nsubj plenti [level]
# plenti compound peopl [funther]
# aggress compound line []
# line compound peopl [aggress]
# peopl compound work [plenti, line]
# enjoy nmod work []
# sever compound work []
# fill compound work []
# cur compound caution []
# caution compound work [cur]
# work compound time [peopl, enjoy, sever, fill, caution]
# balanc compound time []
# time dobj make [work, balanc]
# rightand amod gag []
# run compound gag []
# gag nsubj add [rightand, run]
# add ccomp make [gag, mix]
# littl compound spice []
# spice compound mix [littl]
# mix dobj add [spice]
# well intj say []
# awesom nsubj say []
# say ROOT say [well, awesom, show, add, took]
# leastover compound limit []
# comedi amod work []
# work compound limit [comedi]
# limit compound mention [leastover, work]
# mention dep show [limit]
# later advmod show []
# sectionth amod time []
# action compound time []
# time compound moment [sectionth, action]
# action compound moment []
# moment nsubj show [time, action]
# show ccomp say [mention, later, moment, make]
# marvel nsubj make []
# still advmod make []
# make ccomp show [marvel, still, impress]
# good amod fun []
# fightchoreographi compound fun []
# flavor compound power []
# power compound fun [flavor]
# fun nsubj use [good, fightchoreographi, power]
# use nsubj come [fun, design]
# awesom compound design []
# design dobj use [awesom]
# come compound pretti [use]
# pretti compound moment [come]
# wellsev compound moment []
# moment nsubj impress [pretti, wellsev]
# impress ccomp make [moment, strategi, make]
# strategi dobj impress [behind]
# behind prep strategi [support]
# surpri compound stunt []
# stunt compound moveand [surpri]
# peopl compound moveand []
# moveand compound music [stunt, peopl]
# music nmod support [moveand]
# visual amod support []
# support pobj behind [music, visual]
# help aux make []
# make ccomp impress [help, come, add]
# everyth nsubj come []
# come ccomp make [everyth]
# life compound movi []
# movi compound work [life]
# magic compound filmsthrow []
# love compound filmsthrow []
# filmsthrow compound emot [magic, love]
# emot compound work [filmsthrow]
# moment compound work []
# work nsubj add [movi, emot, moment]
# add ccomp make [work, sever]
# bite compound edg []
# edg compound sever [bite]
# sever dobj add [edg]
# come amod moment []
# moment compound help [come]
# antman compound realli []
# realli compound help [antman]
# help nsubj add [moment, realli]
# add ccomp say [help, come]
# littl compound factor []
# sauc compound factor []
# factor compound mani [littl, sauc]
# mani nsubj come [factor]
# come ccomp add [mani, movi, develop]
# movi dobj come []
# forth advmod charact []
# charact nsubj develop [forth]
# develop advcl come [charact, film]
# time compound film []
# kang nsubj lead []
# lead compound film [kang]
# film dobj develop [time, lead]
# much advmod took []
# took ccomp say [much, moment, amplifi]
# one nummod moment []
# moment dobj took [one]
# amplifi punct took []
# well intj get []
# get ccomp say [well, time, flourish, get, help, load]
# lot compound time []
# time npadvmod get [lot]
# flourish advcl get []
# total amod worth []
# agr amod worth []
# worth amod janet [total, agr]
# ita compound janet []
# scott compound janet []
# janet nsubj get [worth, ita, scott]
# get conj get [janet, moment]
# surpri compound level []
# level compound love [surpri]
# love compound moment [level]
# moment npadvmod get [love]
# realli nsubj help []
# help conj get [realli, seem]
# amplifi nsubj seem []
# seem ccomp help [amplifi, bring]
# somewhat advmod bring []
# forgett compound movi []
# joke compound movi []
# movi compound realli [forgett, joke]
# realli nsubj bring [movi]
# bring ccomp seem [somewhat, realli, hero]
# forefront compound hero []
# hero dobj bring [forefront]
# wantth compound act []
# act compound marvel [wantth]
# marvel nsubj load [act]
# often advmod load []
# load conj get [marvel, often, dud]
# dud dobj load []
# ca aux say []
# nt neg say []
# say parataxis felt [get, ca, nt, see, wow, know, end, see, get, consist, think, yet, got, yet]
# surpri nsubj see []
# see ccomp say [surpri, say]
# strong amod play []
# hand compound play []
# play compound filmid [strong, hand]
# filmid nsubj say [play]
# say ccomp see [filmid, hit, go, stray]
# everyon nsubj hit []
# hit ccomp say [everyon, stick, list]
# mark compound limit []
# limit compound room [mark]
# room compound stick [limit]
# ill compound stick []
# stick dobj hit [room, ill]
# three nummod list []
# top amod list []
# list npadvmod hit [three, top]
# go ccomp say [establish]
# thererudd compound hilari []
# hilari nmod hand [thererudd]
# hand nmod bravado [hilari]
# solid amod bravado []
# balanc compound bravado []
# comedi compound emot []
# emot compound bravado [comedi]
# bravado nsubj establish [hand, solid, balanc, emot]
# establish ccomp go [bravado, movi]
# theme compound movi []
# movi dobj establish [theme]
# often advmod stray []
# stray ccomp say [often, keep]
# overact compound deliveri []
# natur compound deliveri []
# deliveri nsubj keep [overact, natur]
# keep ccomp stray [deliveri, say]
# entertain compound drama []
# drama compound screen [entertain]
# checklilli nmod screen []
# fine amod screen []
# time compound screen []
# screen nsubj say [drama, checklilli, fine, time]
# ca aux say []
# nt neg say []
# say ccomp keep [screen, ca, nt, seem, seen]
# hope compound punch []
# punch compound influenc [hope]
# influenc compound past [punch]
# past nsubj seem [influenc]
# seem ccomp say [past, laid]
# littl nsubj laid []
# laid xcomp seem [littl, back, degr]
# back prt laid []
# lacklust advmod degr []
# final amod degr []
# pick compound degr []
# degr dobj laid [lacklust, final, pick]
# i nsubj seen []
# ve aux seen []
# seen ccomp say [i, ve, filmsmajor, though]
# filmsmajor dobj seen []
# though advmod seen []
# wow cc say []
# major amod man []
# kill compound role []
# role compound man [kill]
# man nsubj know [major, role]
# know parataxis say [man, add]
# articul compound movement []
# movement nsubj add [articul]
# add ccomp know [movement, role, incorpor]
# element compound role []
# speech compound craft []
# craft compound role [speech]
# role dobj add [element, craft]
# well advmod major []
# kang compound layer []
# layer compound major [kang]
# villain compound major []
# major amod destroy [well, layer, villain]
# destroy compound way [major]
# way advmod incorpor [destroy]
# incorpor advcl add [way]
# much amod man []
# one nummod man []
# man nmod pace [much, one, muchdislikesth]
# fantast compound muchdislikesth []
# abil compound muchdislikesth []
# muchdislikesth appos man [fantast, abil]
# pace nmod thing [man]
# fast advmod normal []
# normal amod thing [fast]
# good amod thing []
# thing nsubj end [pace, normal, good]
# end ccomp say [thing, see]
# you nsubj see []
# ll aux see []
# see ccomp end [you, ll, bit]
# might aux bit []
# bit ccomp see [might]
# badquantumania compound realli []
# realli compound lot [badquantumania]
# ...
# dull amod lifeless []
# lifeless nsubj concentr [dull]
# could aux concentr []
# concentr ccomp feel [lifeless, could, go]
# go xcomp concentr []
# bore npadvmod found []
# found advcl feel [bore, point, throughout]
# switch compound variou []
# variou compound point [switch]
# point dobj found [variou]
# throughout prep found []
# scorc compound compar []
# compar compound movi [scorc]
# movi compound wish [compar]
# amu compound park []
# park compound wish [amu]
# wish compound wish [movi, park]
# wish ccomp feel [wish, entertain]
# produc compound moment []
# moment nsubj entertain [produc]
# would aux entertain []
# entertain ccomp wish [moment, would]
# instead advmod feel []
# feel advcl feel [instead, bore, whilst]
# level compound pile []
# morbiu compound pile []
# certainli compound compet []
# compet compound pile [certainli]
# pile compound garbag [level, morbiu, compet]
# garbag nsubj bore [pile]
# equal amod bore []
# bore dobj feel [garbag, equal]
# whilst prep feel [watch]
# watch pcomp whilst [make]
# either preconj make []
# top amod charact []
# charact nsubj make [top]
# make ccomp watch [either, charact, deci, m, buy]
# nonsen compound deci []
# deci ccomp make [nonsen]
# i nsubj m []
# m npadvmod make [i]
# suppo amod buy []
# buy ccomp make [suppo, without]
# without prep buy [think]
# think pcomp without [like]
# much advmod like []
# like prep think [much, pfeiffer]
# michel compound pfeiffer []
# pfeiffer pobj like [michel]
# tell ccomp guess [gener]
# anyon compound moreov []
# kang compound moreov []
# moreov compound gener [anyon, kang]
# funni compound gener []
# gener dobj tell [moreov, funni]
# i nsubj m []
# m ROOT m [i]
# tire compound quippi []
# quippi nsubj inconsequenti [tire]
# inconsequenti ROOT inconsequenti [quippi, marvel, mayb, i, anymor, go, sinc]
# dross compound marvel []
# marvel dobj inconsequenti [dross]
# spew compound mayb []
# mayb npadvmod inconsequenti [spew]
# i npadvmod inconsequenti [m]
# m appos i []
# audienc compound movi []
# movi compound anymor [audienc]
# anymor npadvmod inconsequenti [movi]
# do aux go []
# nt neg go []
# go dep inconsequenti [do, nt, want]
# want xcomp go [feel]
# dislik nsubj want []
# want nsubj feel [dislik]
# feel ccomp want [want, see]
# high amod provid []
# infin compound provid []
# saga compound provid []
# provid nsubj see [high, infin, saga]
# do aux see []
# nt neg see []
# see ccomp feel [provid, do, nt, happen]
# happen xcomp see [except]
# except prep happen [home]
# way advmod home []
# home pcomp except [way, none]
# none appos home []
# movi compound sinc []
# sinc npadvmod inconsequenti [movi]
# endgam compound entertain []
# great amod entertain []
# best advmod theyv []
# theyv compound entertain [best]
# mildli compound entertain []
# entertain nsubj watch [endgam, great, theyv, mildli]
# also advmod watch []
# have aux watch []
# nt neg watch []
# watch ROOT watch [entertain, also, have, nt, show, yet, plan, devot, time, give, perform, incr]
# mcu nsubj show []
# show ccomp watch [mcu]
# yet cc watch []
# i nsubj plan [m]
# m appos i []
# plan conj watch [i, want]
# do aux want []
# nt neg want []
# want xcomp plan [do, nt, life]
# marvel amod life []
# major amod life []
# part compound life []
# life dobj want [marvel, major, part]
# much advmod great []
# great amod devot [much]
# cinema compound devot []
# devot dobj watch [great, cinema]
# much amod time []
# time npadvmod watch [much]
# someth nmod prai []
# mediocr nmod prai []
# highest amod prai []
# prai nsubj give [someth, mediocr, highest]
# give ccomp watch [prai, antman, wasp, short]
# antman dative give []
# wasp dobj give []
# inoffen compound rel []
# rel npadvmod short [inoffen]
# short advmod give [rel]
# although mark perform []
# felt aux perform [long]
# long advmod felt []
# also advmod perform []
# perform advcl watch [although, felt, also, look]
# major amod look []
# paul compound rudd []
# rudd nmod look [paul]
# good nmod film []
# apart advmod cookiecutt []
# cookiecutt nmod film [apart]
# husk compound film []
# film compound look [good, cookiecutt, husk]
# look dobj perform [major, rudd, film]
# incr advcl watch [sell, content]
# artifici compound set []
# design compound set []
# set amod event [artifici, design]
# futur compound event []
# event nsubj sell [set, futur]
# sell conj incr [event, watch]
# watch dobj sell []
# current amod mcu []
# mcu nmod content [current]
# endless amod content []
# trash compound content []
# content dobj incr [mcu, endless, trash]
# i nsubj m []
# m auxpass go [i]
# go ROOT go [m, say, done, found]
# say advcl go [say]
# great amod howev []
# marvel compound howev []
# film compound howev []
# howev nsubj say [great, marvel, film]
# also advmod say []
# wo aux say []
# nt neg say []
# say ccomp say [howev, also, wo, nt, movi, go]
# bad amod movi []
# movi dobj say [bad]
# either preconj lot []
# lot npadvmod thing [either]
# good amod thing []
# thing compound film [good]
# film nsubj thing [thing]
# also advmod thing []
# thing nsubj go [lot, film, also]
# go ccomp say [thing, within]
# within advmod go []
# could aux done []
# done advcl go [could, thing, problem]
# better advmod definit []
# definit nmod thing [better]
# one nummod marvel []
# fillermovi compound marvel []
# marvel compound relea [one, fillermovi]
# relea nmod thing [marvel]
# everi amod thing []
# nowandthen compound tie []
# order compound tie []
# tie compound thing [nowandthen, order]
# thing dobj done [definit, relea, everi, tie]
# togeth nmod problem []
# bigger amod mcu []
# mcu compound franchi [bigger]
# franchi compound problem [mcu]
# main compound plotarc []
# plotarc compound problem [main]
# mcu compound problem []
# problem nmod problem [togeth, franchi, plotarc, mcu]
# due amod problem []
# problem dobj done [problem, due, born]
# born acl problem []
# mani nmod posit []
# good amod posit []
# posit nsubj found [mani, good]
# found conj go [posit, past, thi, need]
# mcu compound past []
# past advmod found [mcu]
# thi prep found [problem]
# problem dobj thi []
# does aux appli []
# nt neg appli []
# appli compound marvel [does, nt]
# fan compound effect []
# effect compound marvel [fan]
# gener compound audienc []
# audienc compound marvel [gener]
# marvel nsubj need [appli, effect, audienc]
# still advmod need []
# need ccomp found [marvel, still, want, fan]
# get nmod event []
# point compound dazzl []
# dazzl nmod event [point]
# audienc amod event []
# huge amod event []
# blockbust compound crossov []
# crossov compound event [blockbust]
# event nsubj want [get, dazzl, audienc, huge, crossov, like]
# like prep event [meantim]
# aveng compound end []
# end compound meantim [aveng]
# game compound meantim []
# meantim pobj like [end, game]
# want ccomp need [event, take]
# take xcomp want [buildup]
# time compound buildup []
# creat compound buildup []
# buildup dobj take [time, creat]
# next amod fan []
# huge amod fan []
# event compound fan []
# fan npadvmod need [next, huge, event]
# okay intj bein []
# gener compound audienc []
# audienc nsubj bein [gener]
# might aux bein []
# bein ROOT bein [okay, audienc, might]
# case compound antman []
# antman compound rudd [case]
# paul compound rudd []
# rudd nsubj make [antman, paul]
# make ROOT make [rudd, found, differ, took, need, begin, get, get]
# sen compound center []
# third amod center []
# film compound center []
# trilog compound center []
# center nsubj found [sen, third, film, trilog, around]
# around prep center [mytho]
# quantum compound realm []
# realm compound mytho [quantum]
# part compound antman []
# antman compound mytho [part]
# mytho pobj around [realm, antman]
# found ccomp make [center, play, set]
# comic amod book []
# book compound plu [comic]
# plu nsubj play [book]
# play ccomp found [plu]
# huge amod role []
# role compound leav [huge]
# main amod stori []
# mcu compound stori []
# stori compound leav [main, mcu]
# leav nsubj set [role, stori]
# set conj found [leav, francisco]
# san compound francisco []
# francisco dobj set [san]
# first amod film []
# two nummod film []
# film nsubj took [first, two]
# took ccomp differ [film, place, go]
# place dobj took []
# go dep took []
# complet nsubj differ []
# differ ccomp make [took, complet, get, develop]
# set amod film []
# film nsubj get [set]
# quick amod director []
# arriv compound quantum []
# quantum compound director [arriv]
# realm compound director []
# director compound reed [quick, quantum, realm]
# peyton compound reed []
# reed nsubj get [director, peyton]
# get advcl differ [film, reed, take]
# right amod plot []
# plot nsubj take [right]
# take ccomp get [plot, u, realm, within]
# u dobj take []
# quantum compound realm []
# realm dobj take [quantum]
# within prep take [film]
# first amod film []
# minut compound film []
# film pobj within [first, minut]
# thi compound problem []
# problem nsubj develop [thi]
# develop advcl differ [problem, reed]
# begin amod director []
# film compound director []
# director nsubj reed [begin, film]
# reed ccomp develop [director]
# much advmod territori []
# territori amod plotpoint [much]
# need compound plotpoint []
# cover compound plotpoint []
# film compound plotpoint []
# plotpoint nsubj took [territori, need, cover, film]
# took ccomp make [plotpoint, away, time]
# away advmod took []
# time npadvmod took []
# need ccomp make [wasp, suffer]
# revisit nmod charact []
# main amod charact []
# charact nsubj wasp [revisit, main]
# wasp ccomp need [charact]
# total amod charact []
# overlook amod charact []
# film compound support []
# support compound charact [film]
# charact compound suffer [total, overlook, support]
# suffer ccomp need [charact]
# begin ccomp make [film]
# film dobj begin []
# quick amod order []
# look compound sloppili []
# sloppili compound order [look]
# forc compound u []
# u compound order [forc]
# order nsubj get [quick, sloppili, u]
# get ccomp make [order, realmth]
# quantum nsubj realmth []
# realmth ccomp get [quantum, charact]
# posit compound side []
# side nmod creat [posit]
# approach compound creat []
# creat nmod new [side, approach]
# whole amod new []
# new nsubj differ [creat, whole]
# differ compound antman [new]
# antman compound antman []
# film compound antman []
# antman compound charact [differ, antman, film]
# wasp compound quantumania []
# quantumania compound charact [wasp]
# contain compound charact []
# side compound charact []
# charact dobj realmth [antman, quantumania, contain, side]
# do aux get []
# nt neg get []
# get advcl make [do, nt, see, thi]
# see xcomp get [bring]
# lot nsubj bring []
# rudd amod tap []
# tap nsubj bring [rudd]
# bring ccomp see [lot, tap, role, like]
# comedicsid amod role []
# role dobj bring [comedicsid]
# much advmod like []
# like prep bring [much, fodder]
# michael compound batman []
# keaton compound batman []
# batman compound actor [michael, keaton]
# actor compound fodder [batman]
# abl compound fodder []
# sell compound charact []
# charact compound fodder [sell]
# seriou compound emot []
# emot compound fodder [seriou]
# superhero compound fodder []
# fodder pobj like [actor, abl, charact, emot, superhero]
# also advmod charact []
# ad nmod splash []
# comedi amod splash []
# splash compound design [ad, comedi]
# design compound charact [splash]
# charact nmod actor [also, design]
# great amod perform []
# perform compound actor [great]
# actor compound rudd [charact, perform]
# evid compound rudd []
# rudd nsubj thi [actor, evid, film]
# first amod film []
# two nummod film []
# antman compound film []
# film appos rudd [first, two, antman]
# thi ccomp get [rudd, reed]
# time compound howev []
# howev compound reed [time]
# peyton compound reed []
# reed dobj thi [howev, peyton]
# decid compound tap []
# tap nmod antman [decid]
# tough amod antman []
# brave amod antman []
# herosid compound antman []
# antman nsubj show [tap, tough, brave, herosid, seen]
# seen acl antman [game]
# aveng compound end []
# end compound game [aveng]
# game dobj seen [end]
# show ROOT show [antman, u, headach, past, gone, lost, hope]
# u dobj show []
# matur compound emot []
# emot compound liber [matur]
# seriou compound success []
# success compound liber [seriou]
# liber compound headach [emot, success]
# scott compound headach []
# lang compound headach []
# headach dobj show [liber, scott, lang]
# past prep show []
# gone conj show [howev]
# howev npadvmod gone []
# five nummod year []
# year compound gap [five]
# gap nsubj lost [year]
# lost ccomp show [gap, mindwith]
# daughter compound kathryn []
# cassi compound kathryn []
# kathryn compound newton [daughter, cassi]
# newton compound mindwith [kathryn]
# weigh compound mindwith []
# mindwith dobj lost [newton, weigh]
# comedysid amod dishedout []
# scott compound lang []
# lang compound dishedout [scott]
# subdu compound dishedout []
# comedi compound dishedout []
# dishedout compound parent [comedysid, lang, subdu, comedi]
# michael compound parent []
# dougla compound parent []
# hank compound parent []
# pym compound parent []
# film compound parent []
# parent compound hope [dishedout, michael, dougla, hank, pym, film]
# hope conj show [parent]
# van compound dyne []
# dyne nsubj wasp [van]
# wasp compound lilli [dyne]
# evangelin compound lilli []
# lilli nsubj play [wasp, evangelin]
# play ROOT play [lilli, thought, thi, goingthroughthemot]
# big amod film []
# role compound film []
# film compound michel [big, role]
# depict compound michel []
# hank compound michel []
# janet compound michel []
# michel compound janet [film, depict, hank, janet]
# pfeiffer compound janet []
# standout compound janet []
# janet compound hank [michel, pfeiffer, standout]
# tough compound hank []
# hank nsubj thought [janet, tough]
# still advmod cool []
# cool amod charact [still]
# origin compound antman []
# antman nmod film [origin]
# wasp nmod film []
# film nmod charact [antman, wasp]
# new amod charact []
# charact nsubj thought [cool, film, new]
# thought ccomp play [hank, charact, good, find, explain]
# pretti compound good []
# good ccomp thought [pretti, like]
# like prep good [creatur]
# veb compound voic []
# voic compound creatur [veb]
# david compound dastmalchian []
# dastmalchian compound creatur [david]
# slime compound creatur []
# creatur pobj like [voic, dastmalchian, slime, ob]
# ob prep creatur [mind]
# hole compound mind []
# quaz compound jackson []
# william compound jackson []
# jackson compound harper [quaz, william]
# harper compound mind [jackson]
# read compound mind []
# mind pobj ob [hole, harper, read]
# cool amod head []
# robotcreatur nmod head []
# whole amod head []
# head compound energyblast [cool, robotcreatur, whole]
# energyblast nsubj find [head]
# ca aux find []
# nt neg find []
# find ccomp thought [energyblast, ca, nt, speak, seem]
# name nsubj speak []
# speak ccomp find [name]
# part compound howev []
# howev nmod charact [part]
# new amod charact []
# charact nsubj seem [howev, new]
# seem ccomp find [charact, perform]
# slightli amod payoff []
# dull amod payoff []
# payoff nsubj perform [slightli, dull]
# well advmod perform []
# perform ccomp seem [payoff, well, film]
# jonathan nmod conqueror []
# major amod conqueror []
# kang compound conqueror []
# conqueror compound film [jonathan, major, kang]
# hi compound film []
# part compound film []
# film dobj perform [conqueror, hi, part]
# explain ccomp thought [answer]
# well advmod answer []
# gener compound audienc []
# audienc compound fan [gener]
# satisfi compound fan []
# fan compound answer [audienc, satisfi]
# see compound answer []
# answer dobj explain [well, fan, see, season]
# look nmod season []
# sinc compound season []
# end compound season []
# season appos answer [look, sinc, end, one]
# one nummod season []
# loki nsubj thi []
# thi advcl play [loki, film]
# film dobj thi []
# goingthroughthemot advcl play [pictur, dull, end]
# bigger amod pictur []
# pictur dobj goingthroughthemot [bigger]
# dull advcl goingthroughthemot []
# certain amod moment []
# moment compound end [certain]
# howev compound effect []
# effect nsubj end [howev]
# end advcl goingthroughthemot [moment, effect, trilog]
# payton compound trilog []
# reed compound trilog []
# trilog dobj end [payton, reed]
# i nsubj m []
# m ccomp come [i, sure]
# sure acomp m [set]
# eventu compound time []
# time npadvmod slip [eventu]
# goe compound film []
# film nsubj slip [goe]
# slip compound rank [time, film]
# lower amod level []
# level compound rank [lower]
# mcu compound rank []
# rank nsubj set [slip, level, mcu]
# set ccomp sure [rank, thing]
# mani nmod scenario []
# interest compound scenario []
# scenario nmod thing [mani, interest]
# new amod thing []
# question compound thing []
# thing dobj set [scenario, new, question]
# come ROOT come [m, imdb]
# c compound imdb []
# mygrad compound imdb []
# imdb attr come [c, mygrad]
# Named Entities:
# ORDINAL: 172
# CARDINAL: 196
# PERSON: 512
# NORP: 32
# GPE: 80
# ORG: 232
# TIME: 8
# DATE: 40
# FAC: 16
# QUANTITY: 4
# PRODUCT: 4
# WORK_OF_ART: 4

# %% [markdown]
# # **Following Questions must answer using AI assitance**

# %% [markdown]
# #Question 4 (20 points).

# %% [markdown]
# Q4. (PART-1)
# Web scraping data from the GitHub Marketplace to gather details about popular actions. Using Python, the process begins by sending HTTP requests to multiple pages of the marketplace (1000 products), handling pagination through dynamic page numbers. The key details extracted include the product name, a short description, and the URL.
#
#  The extracted data is stored in a structured CSV format with columns for product name, description, URL, and page number. A time delay is introduced between requests to avoid server overload. ChatGPT can assist by helping with the parsing of HTML, error handling, and generating reports based on the data collected.
#
#  The goal is to complete the scraping within a specified time limit, ensuring that the process is efficient and adheres to GitHub’s usage guidelines.
#
# (PART -2)
#
# 1.   **Preprocess Data**: Clean the text by tokenizing, removing stopwords, and converting to lowercase.
#
# 2. Perform **Data Quality** operations.
#
#
# Preprocessing:
# Preprocessing involves cleaning the text by removing noise such as special characters, HTML tags, and unnecessary whitespace. It also includes tasks like tokenization, stopword removal, and lemmatization to standardize the text for analysis.
#
# Data Quality:
# Data quality checks ensure completeness, consistency, and accuracy by verifying that all required columns are filled and formatted correctly. Additionally, it involves identifying and removing duplicates, handling missing values, and ensuring the data reflects the true content accurately.

# %% [markdown]
# Github MarketPlace page:
# https://github.com/marketplace?type=actions

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

def scrape_github_marketplace(pages=1, output_csv='github_actions.csv'):
    """
    Scrape GitHub Marketplace (Actions). Adjust pages as needed.
    """
    base_url = "https://github.com/marketplace?type=actions"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
    }

    with open(output_csv, 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(["page_number", "product_name", "product_description", "url"])

        for page_num in range(1, pages + 1):
            url = f"{base_url}&page={page_num}"
            print(f"Scraping: {url}")

            try:
                response = requests.get(url, headers=headers, timeout=10)
                response.raise_for_status()
                print(response)

                soup = BeautifulSoup(response.text, "html.parser")

                # Adjust your selector to match the <article> elements for each action
                product_cards = soup.select("article.Box-row.marketplace-item")
                if not product_cards:
                    print(f"No items found on page {page_num}. Possibly no more pages or structure changed.")
                    break  # Stop scraping further pages if the first page has no results

                for card in product_cards:
                    # 1) Title / Name
                    title_el = card.select_one("h3 a span[itemprop='name']")
                    product_name = title_el.get_text(strip=True) if title_el else "N/A"

                    # 2) Description
                    desc_el = card.select_one("p.color-fg-muted")
                    product_description = desc_el.get_text(strip=True) if desc_el else "N/A"

                    # 3) Link
                    link_el = card.select_one("h3 a[href]")
                    product_url = f"https://github.com{link_el['href']}" if link_el else "N/A"

                    writer.writerow([page_num, product_name, product_description, product_url])

                # Sleep briefly to respect rate limits
                time.sleep(1)

            except requests.exceptions.RequestException as e:
                print(f"Error fetching page {page_num}: {e}")
                continue

if __name__ == "__main__":
    # Scrape just 1 page to test
    scrape_github_marketplace(pages=1, output_csv='github_actions.csv')
# Out:
# Scraping: https://github.com/marketplace?type=actions&page=1
# No items found on page 1. Possibly no more pages or structure changed.

# %%
import requests
from bs4 import BeautifulSoup

# URL of the GitHub Marketplace - Actions section
url = "https://github.com/marketplace?type=actions"

# Define headers to mimic a real browser request
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36 Edge/91.0.864.64",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-US,en;q=0.9",
    "Connection": "keep-alive",
    "Upgrade-Insecure-Requests": "1",
    "Referer": "https://github.com/",
    "TE": "Trailers"
}

# Send GET request with headers
response = requests.get(url, headers=headers)
print(response.text)
if response.status_code != 200:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
    exit()

# Parse the content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find the section containing the actions
actions = soup.find_all('a', class_='btn-link')

# Extract and print the action names and links
for action in actions:
    action_name = action.get_text(strip=True)
    action_url = f"https://github.com{action.get('href')}"
    if action_name:  # to avoid printing empty names
        print(f"Action Name: {action_name}")
        print(f"Link: {action_url}\n")
# Out:
# <!DOCTYPE html>
# <html
#   lang="en"
#
#   data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"
#   data-a11y-animated-images="system" data-a11y-link-underlines="true"
#
#   >
#
#
#
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#   <link rel="preconnect" href="https://github.githubassets.com" crossorigin>
#   <link rel="preconnect" href="https://avatars.githubusercontent.com">
#
#
#
#
#   <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-7aa84bb7e11e.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-f65db3e8d171.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_dimmed-a8258e3c6dda.css" /><link data-color-theme="dark_high_contrast" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_high_contrast-7e97d834719c.css" /><link data-color-theme="dark_colorblind" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_colorblind-01d869f460be.css" /><link data-color-theme="light_colorblind" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_colorblind-534f3e971240.css" /><link data-color-theme="light_high_contrast" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_high_contrast-a8cc7d138001.css" /><link data-color-theme="light_tritanopia" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_tritanopia-35e9dfdc4f9f.css" /><link data-color-theme="dark_tritanopia" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_tritanopia-cf4cc5f62dfe.css" />
#
#     <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/primer-primitives-d9abecd14f1e.css" />
#     <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/primer-93aded0ee8a1.css" />
#     <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/global-8bed0685a4b5.css" />
#     <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/github-a954a02d9269.css" />
#   <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/marketplace-4bc4da71038e.css" />
#
#
#
#
#   <script type="application/json" id="client-env">{"locale":"en","featureFlags":["bypass_copilot_indexing_quota","copilot_immersive_file_preview","copilot_new_references_ui","copilot_attach_folder_reference","copilot_personal_instructions","copilot_personal_instructions_templates","copilot_chat_repo_custom_instructions_preview","copilot_chat_retry_on_error","copilot_chat_persist_submitted_input","copilot_conversational_ux_history_refs","copilot_chat_shared_chat_input","copilot_editor_upsells","copilot_dotcom_chat_reduce_telemetry","copilot_implicit_context","copilot_no_floating_button","copilot_smell_icebreaker_ux","copilot_read_shared_conversation","dotcom_chat_client_side_skills","experimentation_azure_variant_endpoint","failbot_handle_non_errors","geojson_azure_maps","ghost_pilot_confidence_truncation_25","ghost_pilot_confidence_truncation_40","github_models_o3_mini_streaming","hovercard_accessibility","issues_react_remove_placeholders","issues_react_blur_item_picker_on_close","issues_react_include_bots_in_pickers","marketing_pages_search_explore_provider","remove_child_patch","sample_network_conn_type","swp_enterprise_contact_form","site_copilot_extensions_ga","site_copilot_vscode_link_update","site_proxima_australia_update","issues_react_create_milestone","issues_react_cache_fix_workaround","lifecycle_label_name_updates"]}</script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/wp-runtime-c6d50aae516a.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_oddbird_popover-polyfill_dist_popover_js-9da652f58479.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_arianotify-polyfill_ariaNotify-polyfill_js-node_modules_github_mi-3abb8f-d7e6bc799724.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_failbot_failbot_ts-4600dbf2d60a.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/environment-f04cb2a9fc8c.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_behaviors_dist_esm_index_mjs-0dbb79f97f8f.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_selector-observer_dist_index_esm_js-f690fd9ae3d5.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_relative-time-element_dist_index_js-f6da4b3fa34c.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_auto-complete-element_dist_index_js-node_modules_github_catalyst_-8e9f78-a74b4e0a8a6b.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_text-expander-element_dist_index_js-78748950cb0c.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_filter-input-element_dist_index_js-node_modules_github_remote-inp-b5f1d7-a1760ffda83d.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_markdown-toolbar-element_dist_index_js-ceef33f593fa.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_file-attachment-element_dist_index_js-node_modules_primer_view-co-c44a69-f0c8a795d1fd.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/github-elements-44d18ad044b3.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/element-registry-682f1551aebf.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_braintree_browser-detection_dist_browser-detection_js-node_modules_githu-2906d7-2a07a295af40.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_lit-html_lit-html_js-be8cb88f481b.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_morphdom_dist_morphdom-e-7c534c-a4a1922eb55f.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_turbo_dist_turbo_es2017-esm_js-e3cbe28f1638.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-893f9f-6cf3320416b8.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_color-convert_index_js-e3180fe3bcb3.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_quote-selection_dist_index_js-node_modules_github_session-resume_-947061-205cd97df772.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_updatable-content_updatable-content_ts-a1563f62660e.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_task-list_ts-app_assets_modules_github_sso_ts-ui_packages-900dde-f48a418a99d4.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/app_assets_modules_github_sticky-scroll-into-view_ts-8fa27fd7fbb6.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_ajax-error_ts-app_assets_modules_github_behaviors_include-87a4ae-e2caa5390f5a.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_commenting_edit_ts-app_assets_modules_github_behaviors_ht-83c235-783fc7e142e5.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/behaviors-17d1e0503b7c.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_catalyst_lib_index_js-f6223d90c7ba.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/notifications-global-e12489347ccf.js"></script>
#
#   <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/primer-react-9a5713772ca5.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/react-core-af33445b6fc3.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/react-lib-f1bca44e0926.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/octicons-react-611691cca2f6.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_emotion_is-prop-valid_dist_emotion-is-prop-valid_esm_js-node_modules_emo-62da9f-2df2f32ec596.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_stacktrace-parser_dist_s-e7dcdd-f7cc96ebae76.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_oddbird_popover-polyfill_dist_popover-fn_js-55fea94174bf.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_dompurify_dist_purify_js-b89b98661809.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_lodash-es__Stack_js-node_modules_lodash-es__Uint8Array_js-node_modules_l-4faaa6-4a736fde5c2f.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_focus-visible_dist_focus-visible_js-node_modules_fzy_js_index_js-node_mo-c4d1d6-73cf7c06cba8.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_tanstack_query-core_build_modern_queryObserver_js-node_modules_tanstack_-defd52-843b41414e0e.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_hydro-analytics-client_dist_analytics-client_js-node_modules_gith-b846ac-738877ca2286.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_remark-gfm_lib_index_js-node_modules_remark-parse_lib_index_js-node_modu-44d0fc-3771aaaad894.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_highlight_js_lib_index_js-node_modules_tanstack_react-query_build_modern-1f23f4-ccab79e8c043.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_azure_core-auth_dist-esm_src_azureKeyCredential_js-node_modules_azure_se-710d5b-d4d21ab7e161.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_aria-live_aria-live_ts-ui_packages_promise-with-resolvers-polyfill_promise-with-r-17c672-d6b5ea82572a.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_paths_index_ts-c47b35ea29c3.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_ui-commands_ui-commands_ts-e571874765ef.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_filter_utils_index_ts-ui_packages_fuzzy-score_fuzzy-filter_ts-ui_packages_use-ana-3b6d0b-70673e87e68d.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_document-metadata_document-metadata_ts-ui_packages_filter_providers_index_ts-518c821a86f3.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_test-id-props_test-id-props_ts-ui_packages_copilot-markdown_MarkdownRenderer_tsx--f736ee-6c8f611d2eb8.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/marketplace-react-9d11830c1ec3.js"></script>
# <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/primer-react.e159a7f290fa5e4dd43e.module.css" />
# <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/marketplace-react.8ae96e31667e69c983a0.module.css" />
#
#   <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-cbb1ee-b6cf761e4404.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/marketplace-e3e6a4255ac7.js"></script>
#
#
#   <title>Marketplace · GitHub</title>
#
#
#
#   <meta name="route-pattern" content="/marketplace(.:format)" data-turbo-transient>
#   <meta name="route-controller" content="marketplace_searches" data-turbo-transient>
#   <meta name="route-action" content="show" data-turbo-transient>
#
#
#   <meta name="current-catalog-service-hash" content="bd6a962b2d5b5048ba1c14749f3d3e77a48c2f1774b2cd2959cf08b8f5988483">
#
#
#   <meta name="request-id" content="94CC:11FE94:307914E:42D84AA:67B6BEAA" data-pjax-transient="true"/><meta name="html-safe-nonce" content="59797f3486e57bc58c0c93e6a562ff23a0e64f87da24d7f5c2c23acc6ab431ba" data-pjax-transient="true"/><meta name="visitor-payload" content="eyJyZWZlcnJlciI6Imh0dHBzOi8vZ2l0aHViLmNvbS8iLCJyZXF1ZXN0X2lkIjoiOTRDQzoxMUZFOTQ6MzA3OTE0RTo0MkQ4NEFBOjY3QjZCRUFBIiwidmlzaXRvcl9pZCI6IjIwMzg4OTk2OTk2MDY3OTc5OTQiLCJyZWdpb25fZWRnZSI6ImlhZCIsInJlZ2lvbl9yZW5kZXIiOiJpYWQifQ==" data-pjax-transient="true"/><meta name="visitor-hmac" content="db60d4559eb3abe4f8d6288235fe5e224246cbc8bfd6d4c0fd384b0e99f2c708" data-pjax-transient="true"/>
#
#
#
#
#   <meta name="github-keyboard-shortcuts" content="copilot" data-turbo-transient="true" />
#
#
#   <meta name="selected-link" value="/marketplace" data-turbo-transient>
#   <link rel="assets" href="https://github.githubassets.com/">
#
#     <meta name="google-site-verification" content="Apib7-x98H0j5cPqHWwSMm6dNU4GmODRoqxLiDzdx9I">
#
# <meta name="octolytics-url" content="https://collector.github.com/github/collect" />
#
#
#
#
#
#
#
#
#     <meta name="user-login" content="">
#
#
#
#     <meta name="viewport" content="width=device-width">
#
#
#
#       <meta name="description" content="GitHub is where people build software. More than 150 million people use GitHub to discover, fork, and contribute to over 420 million projects.">
#
#       <link rel="search" type="application/opensearchdescription+xml" href="/opensearch.xml" title="GitHub">
#
#     <link rel="fluid-icon" href="https://github.com/fluidicon.png" title="GitHub">
#     <meta property="fb:app_id" content="1401488693436528">
#     <meta name="apple-itunes-app" content="app-id=1477376905, app-argument=https://github.com/marketplace?type=actions" />
#
#       <meta property="og:url" content="https://github.com">
#   <meta property="og:site_name" content="GitHub">
#   <meta property="og:title" content="Build software better, together">
#   <meta property="og:description" content="GitHub is where people build software. More than 150 million people use GitHub to discover, fork, and contribute to over 420 million projects.">
#   <meta property="og:image" content="https://github.githubassets.com/assets/github-logo-55c5b9a1fe52.png">
#   <meta property="og:image:type" content="image/png">
#   <meta property="og:image:width" content="1200">
#   <meta property="og:image:height" content="1200">
#   <meta property="og:image" content="https://github.githubassets.com/assets/github-mark-57519b92ca4e.png">
#   <meta property="og:image:type" content="image/png">
#   <meta property="og:image:width" content="1200">
#   <meta property="og:image:height" content="620">
#   <meta property="og:image" content="https://github.githubassets.com/assets/github-octocat-13c86b8b336d.png">
#   <meta property="og:image:type" content="image/png">
#   <meta property="og:image:width" content="1200">
#   <meta property="og:image:height" content="620">
#
#   <meta property="twitter:site" content="github">
#   <meta property="twitter:site:id" content="13334762">
#   <meta property="twitter:creator" content="github">
#   <meta property="twitter:creator:id" content="13334762">
#   <meta property="twitter:card" content="summary_large_image">
#   <meta property="twitter:title" content="GitHub">
#   <meta property="twitter:description" content="GitHub is where people build software. More than 150 million people use GitHub to discover, fork, and contribute to over 420 million projects.">
#   <meta property="twitter:image" content="https://github.githubassets.com/assets/github-logo-55c5b9a1fe52.png">
#   <meta property="twitter:image:width" content="1200">
#   <meta property="twitter:image:height" content="1200">
#
#
#
#
#       <meta name="hostname" content="github.com">
#
#
#
#         <meta name="expected-hostname" content="github.com">
#
#
#   <meta http-equiv="x-pjax-version" content="b99cccea3e3f17ab6165db33c4f219c176f794a2c8fe67f288d694019566f099" data-turbo-track="reload">
#   <meta http-equiv="x-pjax-csp-version" content="ace39c3b6632770952207593607e6e0be0db363435a8b877b1f96abe6430f345" data-turbo-track="reload">
#   <meta http-equiv="x-pjax-css-version" content="1c71206221e00a0a8e77d94d48d954f34ddbd711c4a0ced954fd49cd786cfa61" data-turbo-track="reload">
#   <meta http-equiv="x-pjax-js-version" content="7e82c4220ec79a588b8ee4781df482abcc1877daea3d5e61982761c4d8d84a54" data-turbo-track="reload">
#
#   <meta name="turbo-cache-control" content="no-preview" data-turbo-transient="">
#
#       <meta name="turbo-cache-control" content="no-cache" data-turbo-transient>
#
#   <meta name="viewport" content="width=device-width">
#   <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/site-f271fae03c1c.css" />
#
#
#
#
#
#     <meta name="turbo-body-classes" content="logged-out env-production page-responsive">
#
#
#   <meta name="browser-stats-url" content="https://api.github.com/_private/browser/stats">
#
#   <meta name="browser-errors-url" content="https://api.github.com/_private/browser/errors">
#
#   <link rel="mask-icon" href="https://github.githubassets.com/assets/pinned-octocat-093da3e6fa40.svg" color="#000000">
#   <link rel="alternate icon" class="js-site-favicon" type="image/png" href="https://github.githubassets.com/favicons/favicon.png">
#   <link rel="icon" class="js-site-favicon" type="image/svg+xml" href="https://github.githubassets.com/favicons/favicon.svg" data-base-href="https://github.githubassets.com/favicons/favicon">
#
# <meta name="theme-color" content="#1e2327">
# <meta name="color-scheme" content="light dark" />
#
#   <meta name="msapplication-TileImage" content="/windows-tile.png">
#   <meta name="msapplication-TileColor" content="#ffffff">
#
#   <link rel="manifest" href="/manifest.json" crossOrigin="use-credentials">
#
#   </head>
#
#   <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
#     <div data-turbo-body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
#
#
#
#     <div class="position-relative header-wrapper js-header-wrapper ">
#       <a href="#start-of-content" data-skip-target-assigned="false" class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content">Skip to content</a>
#
#       <span data-view-component="true" class="progress-pjax-loader Progress position-fixed width-full">
#     <span style="width: 0%;" data-view-component="true" class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis"></span>
# </span>
#
#       <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/keyboard-shortcuts-dialog-6540c642c6aa.js"></script>
# <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/primer-react.e159a7f290fa5e4dd43e.module.css" />
#
# <react-partial
#   partial-name="keyboard-shortcuts-dialog"
#   data-ssr="false"
#   data-attempted-ssr="false"
# >
#
#   <script type="application/json" data-target="react-partial.embeddedData">{"props":{"docsUrl":"https://docs.github.com/get-started/accessibility/keyboard-shortcuts"}}</script>
#   <div data-target="react-partial.reactRoot"></div>
# </react-partial>
#
#
#
#
#
#
#
#
#
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-94fd67-73b675cf164a.js"></script>
# <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/sessions-2d195d11c56b.js"></script>
# <header class="HeaderMktg header-logged-out js-details-container js-header Details f4 py-3" role="banner" data-is-top="true" data-color-mode=light data-light-theme=light data-dark-theme=dark>
#   <h2 class="sr-only">Navigation Menu</h2>
#
#   <button type="button" class="HeaderMktg-backdrop d-lg-none border-0 position-fixed top-0 left-0 width-full height-full js-details-target" aria-label="Toggle navigation">
#     <span class="d-none">Toggle navigation</span>
#   </button>
#
#   <div class="d-flex flex-column flex-lg-row flex-items-center px-3 px-md-4 px-lg-5 height-full position-relative z-1">
#     <div class="d-flex flex-justify-between flex-items-center width-full width-lg-auto">
#       <div class="flex-1">
#         <button aria-label="Toggle navigation" aria-expanded="false" type="button" data-view-component="true" class="js-details-target js-nav-padding-recalculate js-header-menu-toggle Button--link Button--medium Button d-lg-none color-fg-inherit p-1">  <span class="Button-content">
#     <span class="Button-label"><div class="HeaderMenu-toggle-bar rounded my-1"></div>
#             <div class="HeaderMenu-toggle-bar rounded my-1"></div>
#             <div class="HeaderMenu-toggle-bar rounded my-1"></div></span>
#   </span>
# </button>
#       </div>
#
#       <a class="mr-lg-3 color-fg-inherit flex-order-2 js-prevent-focus-on-mobile-nav"
#         href="/"
#         aria-label="Homepage"
#         data-analytics-event="{&quot;category&quot;:&quot;Marketing nav&quot;,&quot;action&quot;:&quot;click to go to homepage&quot;,&quot;label&quot;:&quot;ref_page:Marketing;ref_cta:Logomark;ref_loc:Header&quot;}">
#         <svg height="32" aria-hidden="true" viewBox="0 0 24 24" version="1.1" width="32" data-view-component="true" class="octicon octicon-mark-github">
#     <path d="M12.5.75C6.146.75 1 5.896 1 12.25c0 5.089 3.292 9.387 7.863 10.91.575.101.79-.244.79-.546 0-.273-.014-1.178-.014-2.142-2.889.532-3.636-.704-3.866-1.35-.13-.331-.69-1.352-1.18-1.625-.402-.216-.977-.748-.014-.762.906-.014 1.553.834 1.769 1.179 1.035 1.74 2.688 1.25 3.349.948.1-.747.402-1.25.733-1.538-2.559-.287-5.232-1.279-5.232-5.678 0-1.25.445-2.285 1.178-3.09-.115-.288-.517-1.467.115-3.048 0 0 .963-.302 3.163 1.179.92-.259 1.897-.388 2.875-.388.977 0 1.955.13 2.875.388 2.2-1.495 3.162-1.179 3.162-1.179.633 1.581.23 2.76.115 3.048.733.805 1.179 1.825 1.179 3.09 0 4.413-2.688 5.39-5.247 5.678.417.36.776 1.05.776 2.128 0 1.538-.014 2.774-.014 3.162 0 .302.216.662.79.547C20.709 21.637 24 17.324 24 12.25 24 5.896 18.854.75 12.5.75Z"></path>
# </svg>
#       </a>
#
#       <div class="flex-1 flex-order-2 text-right">
#           <a
#             href="/login?return_to=https%3A%2F%2Fgithub.com%2Fmarketplace%3Ftype%3Dactions"
#             class="HeaderMenu-link HeaderMenu-button d-inline-flex d-lg-none flex-order-1 f5 no-underline border color-border-default rounded-2 px-2 py-1 color-fg-inherit js-prevent-focus-on-mobile-nav"
#             data-hydro-click="{&quot;event_type&quot;:&quot;authentication.click&quot;,&quot;payload&quot;:{&quot;location_in_page&quot;:&quot;site header menu&quot;,&quot;repository_id&quot;:null,&quot;auth_type&quot;:&quot;SIGN_UP&quot;,&quot;originating_url&quot;:&quot;https://github.com/marketplace?type=actions&quot;,&quot;user_id&quot;:null}}" data-hydro-click-hmac="27470efc17ac363bc3b6021b5c0c2c33a15705e68019a1718b94d4dc31cc11b2"
#             data-analytics-event="{&quot;category&quot;:&quot;Marketing nav&quot;,&quot;action&quot;:&quot;click to Sign in&quot;,&quot;label&quot;:&quot;ref_page:Marketing;ref_cta:Sign in;ref_loc:Header&quot;}"
#           >
#             Sign in
#           </a>
#       </div>
#     </div>
#
#
#     <div class="HeaderMenu js-header-menu height-fit position-lg-relative d-lg-flex flex-column flex-auto top-0">
#       <div class="HeaderMenu-wrapper d-flex flex-column flex-self-start flex-lg-row flex-auto rounded rounded-lg-0">
#           <nav class="HeaderMenu-nav" aria-label="Global">
#             <ul class="d-lg-flex list-style-none">
#                 <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">
#       <button type="button" class="HeaderMenu-link border-0 width-full width-lg-auto px-0 px-lg-2 py-lg-2 no-wrap d-flex flex-items-center flex-justify-between js-details-target" aria-expanded="false">
#         Product
#         <svg opacity="0.5" aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1">
#     <path d="M12.78 5.22a.749.749 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.06 0L3.22 6.28a.749.749 0 1 1 1.06-1.06L8 8.939l3.72-3.719a.749.749 0 0 1 1.06 0Z"></path>
# </svg>
#       </button>
#       <div class="HeaderMenu-dropdown dropdown-menu rounded m-0 p-0 pt-2 pt-lg-4 position-relative position-lg-absolute left-0 left-lg-n3 pb-2 pb-lg-4 d-lg-flex flex-wrap dropdown-menu-wide">
#           <div class="HeaderMenu-column px-lg-4 border-lg-right mb-4 mb-lg-0 pr-lg-7">
#               <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0">
#                 <ul class="list-style-none f5" >
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;github_copilot&quot;,&quot;context&quot;:&quot;product&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;github_copilot_link_product_navbar&quot;}" href="https://github.com/features/copilot">
#       <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-copilot color-fg-subtle mr-3">
#     <path d="M23.922 16.992c-.861 1.495-5.859 5.023-11.922 5.023-6.063 0-11.061-3.528-11.922-5.023A.641.641 0 0 1 0 16.736v-2.869a.841.841 0 0 1 .053-.22c.372-.935 1.347-2.292 2.605-2.656.167-.429.414-1.055.644-1.517a10.195 10.195 0 0 1-.052-1.086c0-1.331.282-2.499 1.132-3.368.397-.406.89-.717 1.474-.952 1.399-1.136 3.392-2.093 6.122-2.093 2.731 0 4.767.957 6.166 2.093.584.235 1.077.546 1.474.952.85.869 1.132 2.037 1.132 3.368 0 .368-.014.733-.052 1.086.23.462.477 1.088.644 1.517 1.258.364 2.233 1.721 2.605 2.656a.832.832 0 0 1 .053.22v2.869a.641.641 0 0 1-.078.256ZM12.172 11h-.344a4.323 4.323 0 0 1-.355.508C10.703 12.455 9.555 13 7.965 13c-1.725 0-2.989-.359-3.782-1.259a2.005 2.005 0 0 1-.085-.104L4 11.741v6.585c1.435.779 4.514 2.179 8 2.179 3.486 0 6.565-1.4 8-2.179v-6.585l-.098-.104s-.033.045-.085.104c-.793.9-2.057 1.259-3.782 1.259-1.59 0-2.738-.545-3.508-1.492a4.323 4.323 0 0 1-.355-.508h-.016.016Zm.641-2.935c.136 1.057.403 1.913.878 2.497.442.544 1.134.938 2.344.938 1.573 0 2.292-.337 2.657-.751.384-.435.558-1.15.558-2.361 0-1.14-.243-1.847-.705-2.319-.477-.488-1.319-.862-2.824-1.025-1.487-.161-2.192.138-2.533.529-.269.307-.437.808-.438 1.578v.021c0 .265.021.562.063.893Zm-1.626 0c.042-.331.063-.628.063-.894v-.02c-.001-.77-.169-1.271-.438-1.578-.341-.391-1.046-.69-2.533-.529-1.505.163-2.347.537-2.824 1.025-.462.472-.705 1.179-.705 2.319 0 1.211.175 1.926.558 2.361.365.414 1.084.751 2.657.751 1.21 0 1.902-.394 2.344-.938.475-.584.742-1.44.878-2.497Z"></path><path d="M14.5 14.25a1 1 0 0 1 1 1v2a1 1 0 0 1-2 0v-2a1 1 0 0 1 1-1Zm-5 0a1 1 0 0 1 1 1v2a1 1 0 0 1-2 0v-2a1 1 0 0 1 1-1Z"></path>
# </svg>
#       <div>
#         <div class="color-fg-default h4">GitHub Copilot</div>
#         Write better code with AI
#       </div>
#
#
# </a></li>
#
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;security&quot;,&quot;context&quot;:&quot;product&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;security_link_product_navbar&quot;}" href="https://github.com/features/security">
#       <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-shield-check color-fg-subtle mr-3">
#     <path d="M16.53 9.78a.75.75 0 0 0-1.06-1.06L11 13.19l-1.97-1.97a.75.75 0 0 0-1.06 1.06l2.5 2.5a.75.75 0 0 0 1.06 0l5-5Z"></path><path d="m12.54.637 8.25 2.675A1.75 1.75 0 0 1 22 4.976V10c0 6.19-3.771 10.704-9.401 12.83a1.704 1.704 0 0 1-1.198 0C5.77 20.705 2 16.19 2 10V4.976c0-.758.489-1.43 1.21-1.664L11.46.637a1.748 1.748 0 0 1 1.08 0Zm-.617 1.426-8.25 2.676a.249.249 0 0 0-.173.237V10c0 5.46 3.28 9.483 8.43 11.426a.199.199 0 0 0 .14 0C17.22 19.483 20.5 15.461 20.5 10V4.976a.25.25 0 0 0-.173-.237l-8.25-2.676a.253.253 0 0 0-.154 0Z"></path>
# </svg>
#       <div>
#         <div class="color-fg-default h4">Security</div>
#         Find and fix vulnerabilities
#       </div>
#
#
# </a></li>
#
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;actions&quot;,&quot;context&quot;:&quot;product&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;actions_link_product_navbar&quot;}" href="https://github.com/features/actions">
#       <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-workflow color-fg-subtle mr-3">
#     <path d="M1 3a2 2 0 0 1 2-2h6.5a2 2 0 0 1 2 2v6.5a2 2 0 0 1-2 2H7v4.063C7 16.355 7.644 17 8.438 17H12.5v-2.5a2 2 0 0 1 2-2H21a2 2 0 0 1 2 2V21a2 2 0 0 1-2 2h-6.5a2 2 0 0 1-2-2v-2.5H8.437A2.939 2.939 0 0 1 5.5 15.562V11.5H3a2 2 0 0 1-2-2Zm2-.5a.5.5 0 0 0-.5.5v6.5a.5.5 0 0 0 .5.5h6.5a.5.5 0 0 0 .5-.5V3a.5.5 0 0 0-.5-.5ZM14.5 14a.5.5 0 0 0-.5.5V21a.5.5 0 0 0 .5.5H21a.5.5 0 0 0 .5-.5v-6.5a.5.5 0 0 0-.5-.5Z"></path>
# </svg>
#       <div>
#         <div class="color-fg-default h4">Actions</div>
#         Automate any workflow
#       </div>
#
#
# </a></li>
#
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;codespaces&quot;,&quot;context&quot;:&quot;product&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;codespaces_link_product_navbar&quot;}" href="https://github.com/features/codespaces">
#       <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-codespaces color-fg-subtle mr-3">
#     <path d="M3.5 3.75C3.5 2.784 4.284 2 5.25 2h13.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0 1 18.75 13H5.25a1.75 1.75 0 0 1-1.75-1.75Zm-2 12c0-.966.784-1.75 1.75-1.75h17.5c.966 0 1.75.784 1.75 1.75v4a1.75 1.75 0 0 1-1.75 1.75H3.25a1.75 1.75 0 0 1-1.75-1.75ZM5.25 3.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h13.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Zm-2 12a.25.25 0 0 0-.25.25v4c0 .138.112.25.25.25h17.5a.25.25 0 0 0 .25-.25v-4a.25.25 0 0 0-.25-.25Z"></path><path d="M10 17.75a.75.75 0 0 1 .75-.75h6.5a.75.75 0 0 1 0 1.5h-6.5a.75.75 0 0 1-.75-.75Zm-4 0a.75.75 0 0 1 .75-.75h.5a.75.75 0 0 1 0 1.5h-.5a.75.75 0 0 1-.75-.75Z"></path>
# </svg>
#       <div>
#         <div class="color-fg-default h4">Codespaces</div>
#         Instant dev environments
#       </div>
#
#
# </a></li>
#
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;issues&quot;,&quot;context&quot;:&quot;product&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;issues_link_product_navbar&quot;}" href="https://github.com/features/issues">
#       <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-issue-opened color-fg-subtle mr-3">
#     <path d="M12 1c6.075 0 11 4.925 11 11s-4.925 11-11 11S1 18.075 1 12 5.925 1 12 1ZM2.5 12a9.5 9.5 0 0 0 9.5 9.5 9.5 9.5 0 0 0 9.5-9.5A9.5 9.5 0 0 0 12 2.5 9.5 9.5 0 0 0 2.5 12Zm9.5 2a2 2 0 1 1-.001-3.999A2 2 0 0 1 12 14Z"></path>
# </svg>
#       <div>
#         <div class="color-fg-default h4">Issues</div>
#         Plan and track work
#       </div>
#
#
# </a></li>
#
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;code_review&quot;,&quot;context&quot;:&quot;product&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;code_review_link_product_navbar&quot;}" href="https://github.com/features/code-review">
#       <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-code-review color-fg-subtle mr-3">
#     <path d="M10.3 6.74a.75.75 0 0 1-.04 1.06l-2.908 2.7 2.908 2.7a.75.75 0 1 1-1.02 1.1l-3.5-3.25a.75.75 0 0 1 0-1.1l3.5-3.25a.75.75 0 0 1 1.06.04Zm3.44 1.06a.75.75 0 1 1 1.02-1.1l3.5 3.25a.75.75 0 0 1 0 1.1l-3.5 3.25a.75.75 0 1 1-1.02-1.1l2.908-2.7-2.908-2.7Z"></path><path d="M1.5 4.25c0-.966.784-1.75 1.75-1.75h17.5c.966 0 1.75.784 1.75 1.75v12.5a1.75 1.75 0 0 1-1.75 1.75h-9.69l-3.573 3.573A1.458 1.458 0 0 1 5 21.043V18.5H3.25a1.75 1.75 0 0 1-1.75-1.75ZM3.25 4a.25.25 0 0 0-.25.25v12.5c0 .138.112.25.25.25h2.5a.75.75 0 0 1 .75.75v3.19l3.72-3.72a.749.749 0 0 1 .53-.22h10a.25.25 0 0 0 .25-.25V4.25a.25.25 0 0 0-.25-.25Z"></path>
# </svg>
#       <div>
#         <div class="color-fg-default h4">Code Review</div>
#         Manage code changes
#       </div>
#
#
# </a></li>
#
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description pb-lg-3" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;discussions&quot;,&quot;context&quot;:&quot;product&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;discussions_link_product_navbar&quot;}" href="https://github.com/features/discussions">
#       <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-comment-discussion color-fg-subtle mr-3">
#     <path d="M1.75 1h12.5c.966 0 1.75.784 1.75 1.75v9.5A1.75 1.75 0 0 1 14.25 14H8.061l-2.574 2.573A1.458 1.458 0 0 1 3 15.543V14H1.75A1.75 1.75 0 0 1 0 12.25v-9.5C0 1.784.784 1 1.75 1ZM1.5 2.75v9.5c0 .138.112.25.25.25h2a.75.75 0 0 1 .75.75v2.19l2.72-2.72a.749.749 0 0 1 .53-.22h6.5a.25.25 0 0 0 .25-.25v-9.5a.25.25 0 0 0-.25-.25H1.75a.25.25 0 0 0-.25.25Z"></path><path d="M22.5 8.75a.25.25 0 0 0-.25-.25h-3.5a.75.75 0 0 1 0-1.5h3.5c.966 0 1.75.784 1.75 1.75v9.5A1.75 1.75 0 0 1 22.25 20H21v1.543a1.457 1.457 0 0 1-2.487 1.03L15.939 20H10.75A1.75 1.75 0 0 1 9 18.25v-1.465a.75.75 0 0 1 1.5 0v1.465c0 .138.112.25.25.25h5.5a.75.75 0 0 1 .53.22l2.72 2.72v-2.19a.75.75 0 0 1 .75-.75h2a.25.25 0 0 0 .25-.25v-9.5Z"></path>
# </svg>
#       <div>
#         <div class="color-fg-default h4">Discussions</div>
#         Collaborate outside of code
#       </div>
#
#
# </a></li>
#
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center Link--has-description" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;code_search&quot;,&quot;context&quot;:&quot;product&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;code_search_link_product_navbar&quot;}" href="https://github.com/features/code-search">
#       <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-code-square color-fg-subtle mr-3">
#     <path d="M10.3 8.24a.75.75 0 0 1-.04 1.06L7.352 12l2.908 2.7a.75.75 0 1 1-1.02 1.1l-3.5-3.25a.75.75 0 0 1 0-1.1l3.5-3.25a.75.75 0 0 1 1.06.04Zm3.44 1.06a.75.75 0 1 1 1.02-1.1l3.5 3.25a.75.75 0 0 1 0 1.1l-3.5 3.25a.75.75 0 1 1-1.02-1.1l2.908-2.7-2.908-2.7Z"></path><path d="M2 3.75C2 2.784 2.784 2 3.75 2h16.5c.966 0 1.75.784 1.75 1.75v16.5A1.75 1.75 0 0 1 20.25 22H3.75A1.75 1.75 0 0 1 2 20.25Zm1.75-.25a.25.25 0 0 0-.25.25v16.5c0 .138.112.25.25.25h16.5a.25.25 0 0 0 .25-.25V3.75a.25.25 0 0 0-.25-.25Z"></path>
# </svg>
#       <div>
#         <div class="color-fg-default h4">Code Search</div>
#         Find more, search less
#       </div>
#
#
# </a></li>
#
#                 </ul>
#               </div>
#           </div>
#           <div class="HeaderMenu-column px-lg-4">
#               <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0 border-bottom-0">
#                     <span class="d-block h4 color-fg-default my-1" id="product-explore-heading">Explore</span>
#                 <ul class="list-style-none f5" aria-labelledby="product-explore-heading">
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;all_features&quot;,&quot;context&quot;:&quot;product&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;all_features_link_product_navbar&quot;}" href="https://github.com/features">
#       All features
#
#
# </a></li>
#
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary Link--external" target="_blank" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;documentation&quot;,&quot;context&quot;:&quot;product&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;documentation_link_product_navbar&quot;}" href="https://docs.github.com">
#       Documentation
#
#     <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle">
#     <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
#
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary Link--external" target="_blank" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;github_skills&quot;,&quot;context&quot;:&quot;product&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;github_skills_link_product_navbar&quot;}" href="https://skills.github.com">
#       GitHub Skills
#
#     <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle">
#     <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
#
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary Link--external" target="_blank" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;blog&quot;,&quot;context&quot;:&quot;product&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;blog_link_product_navbar&quot;}" href="https://github.blog">
#       Blog
#
#     <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle">
#     <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
# </svg>
# </a></li>
#
#                 </ul>
#               </div>
#           </div>
#       </div>
# </li>
#
#                   <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">
#       <button type="button" class="HeaderMenu-link border-0 width-full width-lg-auto px-0 px-lg-2 py-lg-2 no-wrap d-flex flex-items-center flex-justify-between js-details-target" aria-expanded="false">
#         Solutions
#         <svg opacity="0.5" aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1">
#     <path d="M12.78 5.22a.749.749 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.06 0L3.22 6.28a.749.749 0 1 1 1.06-1.06L8 8.939l3.72-3.719a.749.749 0 0 1 1.06 0Z"></path>
# </svg>
#       </button>
#       <div class="HeaderMenu-dropdown dropdown-menu rounded m-0 p-0 pt-2 pt-lg-4 position-relative position-lg-absolute left-0 left-lg-n3 d-lg-flex flex-wrap dropdown-menu-wide">
#           <div class="HeaderMenu-column px-lg-4 border-lg-right mb-4 mb-lg-0 pr-lg-7">
#               <div class="border-bottom pb-3 pb-lg-0 border-lg-bottom-0 pb-lg-3 mb-3 mb-lg-0">
#                     <span class="d-block h4 color-fg-default my-1" id="solutions-by-company-size-heading">By company size</span>
#                 <ul class="list-style-none f5" aria-labelledby="solutions-by-company-size-heading">
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;enterprises&quot;,&quot;context&quot;:&quot;solutions&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;enterprises_link_solutions_navbar&quot;}" href="https://github.com/enterprise">
#       Enterprises
#
#
# </a></li>
#
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;small_and_medium_teams&quot;,&quot;context&quot;:&quot;solutions&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;small_and_medium_teams_link_solutions_navbar&quot;}" href="https://github.com/team">
#       Small and medium teams
#
#
# </a></li>
#
#                     <li>
#   <a class="HeaderMenu-dropdown-link d-block no-underline position-relative py-2 Link--secondary" data-analytics-event="{&quot;location&quot;:&quot;navbar&quot;,&quot;action&quot;:&quot;startups&quot;,&quot;context&quot;:&quot;solutions&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;startups_link_solutions_navbar&quot;}" href="https://github.com/enterprise/startups">
#       Startups
#
#
# </a></li>
#
#                     <li>
# ...
#           </li>
#
#           <li class="mx-2">
#             <a class="Link--secondary" data-analytics-event="{&quot;location&quot;:&quot;footer&quot;,&quot;action&quot;:&quot;privacy&quot;,&quot;context&quot;:&quot;subfooter&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;privacy_link_subfooter_footer&quot;}" href="https://docs.github.com/site-policy/privacy-policies/github-privacy-statement">Privacy</a>
#             (<a href="https://github.com/github/site-policy/pull/582" class="Link--secondary">Updated <time datetime="2022-08">02/2024</time></a>)
#           </li>
#
#           <li class="mx-2">
#             <a class="Link--secondary" data-analytics-event="{&quot;location&quot;:&quot;footer&quot;,&quot;action&quot;:&quot;sitemap&quot;,&quot;context&quot;:&quot;subfooter&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;sitemap_link_subfooter_footer&quot;}" href="/sitemap">Sitemap</a>
#           </li>
#
#           <li class="mx-2">
#             <a class="Link--secondary" data-analytics-event="{&quot;location&quot;:&quot;footer&quot;,&quot;action&quot;:&quot;what_is_git&quot;,&quot;context&quot;:&quot;subfooter&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;what_is_git_link_subfooter_footer&quot;}" href="/git-guides">What is Git?</a>
#           </li>
#
#             <li class="mx-2" >
#   <cookie-consent-link>
#     <button
#       type="button"
#       class="Link--secondary underline-on-hover border-0 p-0 color-bg-transparent"
#       data-action="click:cookie-consent-link#showConsentManagement"
#       data-analytics-event="{&quot;location&quot;:&quot;footer&quot;,&quot;action&quot;:&quot;cookies&quot;,&quot;context&quot;:&quot;subfooter&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;cookies_link_subfooter_footer&quot;}"
#     >
#       Manage cookies
#     </button>
#   </cookie-consent-link>
# </li>
#
# <li class="mx-2">
#   <cookie-consent-link>
#     <button
#       type="button"
#       class="Link--secondary underline-on-hover border-0 p-0 color-bg-transparent"
#       data-action="click:cookie-consent-link#showConsentManagement"
#       data-analytics-event="{&quot;location&quot;:&quot;footer&quot;,&quot;action&quot;:&quot;dont_share_info&quot;,&quot;context&quot;:&quot;subfooter&quot;,&quot;tag&quot;:&quot;link&quot;,&quot;label&quot;:&quot;dont_share_info_link_subfooter_footer&quot;}"
#     >
#       Do not share my personal information
#     </button>
#   </cookie-consent-link>
# </li>
#
#         </ul>
#       </nav>
#
#       <nav aria-label="GitHub&#39;s Social Media Links" class="mt-3 mt-md-0">
#
# <ul class="list-style-none d-flex flex-items-center lh-condensed-ultra">
#     <li class="ml-md-3">
#       <a href="https://www.linkedin.com/company/github" class="footer-social-icon d-block Link--outlineOffset" data-analytics-event="{&quot;category&quot;:&quot;Footer&quot;,&quot;action&quot;:&quot;go to Linkedin&quot;,&quot;label&quot;:&quot;text:text:linkedin&quot;}">
#         <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 19 18" aria-hidden="true" class="d-block" width="19" height="18"><path d="M3.94 2A2 2 0 1 1 2 0a2 2 0 0 1 1.94 2zM4 5.48H0V18h4zm6.32 0H6.34V18h3.94v-6.57c0-3.66 4.77-4 4.77 0V18H19v-7.93c0-6.17-7.06-5.94-8.72-2.91z" fill="currentColor"></path></svg>
#
#         <span class="sr-only">GitHub on LinkedIn</span>
#       </a>
#     </li>
#     <li class="ml-3">
#       <a href="https://www.instagram.com/github" class="footer-social-icon d-block Link--outlineOffset" data-analytics-event="{&quot;category&quot;:&quot;Footer&quot;,&quot;action&quot;:&quot;go to Instagram&quot;,&quot;label&quot;:&quot;text:text:instagram&quot;}">
#         <svg xmlns="http://www.w3.org/2000/svg" role="img" viewBox="0 0 24 24" aria-hidden="true" class="d-block" width="18" height="18"><title>Instagram</title><path d="M12 0C8.74 0 8.333.015 7.053.072 5.775.132 4.905.333 4.14.63c-.789.306-1.459.717-2.126 1.384S.935 3.35.63 4.14C.333 4.905.131 5.775.072 7.053.012 8.333 0 8.74 0 12s.015 3.667.072 4.947c.06 1.277.261 2.148.558 2.913.306.788.717 1.459 1.384 2.126.667.666 1.336 1.079 2.126 1.384.766.296 1.636.499 2.913.558C8.333 23.988 8.74 24 12 24s3.667-.015 4.947-.072c1.277-.06 2.148-.262 2.913-.558.788-.306 1.459-.718 2.126-1.384.666-.667 1.079-1.335 1.384-2.126.296-.765.499-1.636.558-2.913.06-1.28.072-1.687.072-4.947s-.015-3.667-.072-4.947c-.06-1.277-.262-2.149-.558-2.913-.306-.789-.718-1.459-1.384-2.126C21.319 1.347 20.651.935 19.86.63c-.765-.297-1.636-.499-2.913-.558C15.667.012 15.26 0 12 0zm0 2.16c3.203 0 3.585.016 4.85.071 1.17.055 1.805.249 2.227.415.562.217.96.477 1.382.896.419.42.679.819.896 1.381.164.422.36 1.057.413 2.227.057 1.266.07 1.646.07 4.85s-.015 3.585-.074 4.85c-.061 1.17-.256 1.805-.421 2.227-.224.562-.479.96-.899 1.382-.419.419-.824.679-1.38.896-.42.164-1.065.36-2.235.413-1.274.057-1.649.07-4.859.07-3.211 0-3.586-.015-4.859-.074-1.171-.061-1.816-.256-2.236-.421-.569-.224-.96-.479-1.379-.899-.421-.419-.69-.824-.9-1.38-.165-.42-.359-1.065-.42-2.235-.045-1.26-.061-1.649-.061-4.844 0-3.196.016-3.586.061-4.861.061-1.17.255-1.814.42-2.234.21-.57.479-.96.9-1.381.419-.419.81-.689 1.379-.898.42-.166 1.051-.361 2.221-.421 1.275-.045 1.65-.06 4.859-.06l.045.03zm0 3.678c-3.405 0-6.162 2.76-6.162 6.162 0 3.405 2.76 6.162 6.162 6.162 3.405 0 6.162-2.76 6.162-6.162 0-3.405-2.76-6.162-6.162-6.162zM12 16c-2.21 0-4-1.79-4-4s1.79-4 4-4 4 1.79 4 4-1.79 4-4 4zm7.846-10.405c0 .795-.646 1.44-1.44 1.44-.795 0-1.44-.646-1.44-1.44 0-.794.646-1.439 1.44-1.439.793-.001 1.44.645 1.44 1.439z" fill="currentColor"></path></svg>
#
#         <span class="sr-only">GitHub on Instagram</span>
#       </a>
#     </li>
#     <li class="ml-3">
#       <a href="https://www.youtube.com/github" class="footer-social-icon d-block Link--outlineOffset" data-analytics-event="{&quot;category&quot;:&quot;Footer&quot;,&quot;action&quot;:&quot;go to YouTube&quot;,&quot;label&quot;:&quot;text:text:youtube&quot;}">
#         <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 19.17 13.6" aria-hidden="true" class="d-block" width="23" height="16"><path d="M18.77 2.13A2.4 2.4 0 0 0 17.09.42C15.59 0 9.58 0 9.58 0a57.55 57.55 0 0 0-7.5.4A2.49 2.49 0 0 0 .39 2.13 26.27 26.27 0 0 0 0 6.8a26.15 26.15 0 0 0 .39 4.67 2.43 2.43 0 0 0 1.69 1.71c1.52.42 7.5.42 7.5.42a57.69 57.69 0 0 0 7.51-.4 2.4 2.4 0 0 0 1.68-1.71 25.63 25.63 0 0 0 .4-4.67 24 24 0 0 0-.4-4.69zM7.67 9.71V3.89l5 2.91z" fill="currentColor"></path></svg>
#
#         <span class="sr-only">GitHub on YouTube</span>
#       </a>
#     </li>
#     <li class="ml-3">
#       <a href="https://x.com/github" class="footer-social-icon d-block Link--outlineOffset" data-analytics-event="{&quot;category&quot;:&quot;Footer&quot;,&quot;action&quot;:&quot;go to X&quot;,&quot;label&quot;:&quot;text:text:x&quot;}">
#         <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 1200 1227" fill="currentColor" aria-hidden="true" class="d-block" width="16" height="16"><path d="M714.163 519.284 1160.89 0h-105.86L667.137 450.887 357.328 0H0l468.492 681.821L0 1226.37h105.866l409.625-476.152 327.181 476.152H1200L714.137 519.284h.026ZM569.165 687.828l-47.468-67.894-377.686-540.24h162.604l304.797 435.991 47.468 67.894 396.2 566.721H892.476L569.165 687.854v-.026Z"></path></svg>
#
#         <span class="sr-only">GitHub on X</span>
#       </a>
#     </li>
#     <li class="ml-3">
#       <a href="https://www.tiktok.com/@github" class="footer-social-icon d-block Link--outlineOffset" data-analytics-event="{&quot;category&quot;:&quot;Footer&quot;,&quot;action&quot;:&quot;go to tiktok&quot;,&quot;label&quot;:&quot;text:text:tiktok&quot;}">
#         <svg xmlns="http://www.w3.org/2000/svg" role="img" viewBox="0 0 24 24" aria-hidden="true" class="d-block" width="18" height="18"><title>TikTok</title><path d="M12.525.02c1.31-.02 2.61-.01 3.91-.02.08 1.53.63 3.09 1.75 4.17 1.12 1.11 2.7 1.62 4.24 1.79v4.03c-1.44-.05-2.89-.35-4.2-.97-.57-.26-1.1-.59-1.62-.93-.01 2.92.01 5.84-.02 8.75-.08 1.4-.54 2.79-1.35 3.94-1.31 1.92-3.58 3.17-5.91 3.21-1.43.08-2.86-.31-4.08-1.03-2.02-1.19-3.44-3.37-3.65-5.71-.02-.5-.03-1-.01-1.49.18-1.9 1.12-3.72 2.58-4.96 1.66-1.44 3.98-2.13 6.15-1.72.02 1.48-.04 2.96-.04 4.44-.99-.32-2.15-.23-3.02.37-.63.41-1.11 1.04-1.36 1.75-.21.51-.15 1.07-.14 1.61.24 1.64 1.82 3.02 3.5 2.87 1.12-.01 2.19-.66 2.77-1.61.19-.33.4-.67.41-1.06.1-1.79.06-3.57.07-5.36.01-4.03-.01-8.05.02-12.07z" fill="currentColor"></path></svg>
#
#         <span class="sr-only">GitHub on TikTok</span>
#       </a>
#     </li>
#     <li class="ml-3">
#       <a href="https://www.twitch.tv/github" class="footer-social-icon d-block Link--outlineOffset" data-analytics-event="{&quot;category&quot;:&quot;Footer&quot;,&quot;action&quot;:&quot;go to Twitch&quot;,&quot;label&quot;:&quot;text:text:twitch&quot;}">
#         <svg xmlns="http://www.w3.org/2000/svg" role="img" viewBox="0 0 24 24" aria-hidden="true" class="d-block" width="18" height="18"><title>Twitch</title><path d="M11.571 4.714h1.715v5.143H11.57zm4.715 0H18v5.143h-1.714zM6 0L1.714 4.286v15.428h5.143V24l4.286-4.286h3.428L22.286 12V0zm14.571 11.143l-3.428 3.428h-3.429l-3 3v-3H6.857V1.714h13.714Z" fill="currentColor"></path></svg>
#
#         <span class="sr-only">GitHub on Twitch</span>
#       </a>
#     </li>
#     <li class="ml-3">
#       <a href="https://github.com/github" class="footer-social-icon d-block Link--outlineOffset" data-analytics-event="{&quot;category&quot;:&quot;Footer&quot;,&quot;action&quot;:&quot;go to github&#39;s org&quot;,&quot;label&quot;:&quot;text:text:github&quot;}">
#         <svg xmlns="http://www.w3.org/2000/svg" height="20" viewBox="0 0 16 16" width="20" aria-hidden="true" class="d-block"><path fill="currentColor" d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z"></path></svg>
#
#         <span class="sr-only">GitHub’s organization on GitHub</span>
#       </a>
#     </li>
# </ul>
#
#       </nav>
#     </div>
#   </div>
# </footer>
#
#
#
#     <ghcc-consent id="ghcc" class="position-fixed bottom-0 left-0" style="z-index: 999999" data-initial-cookie-consent-allowed="" data-cookie-consent-required="false"></ghcc-consent>
#
#
#
#   <div id="ajax-error-message" class="ajax-error-message flash flash-error" hidden>
#     <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-alert">
#     <path d="M6.457 1.047c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0 1 14.082 15H1.918a1.75 1.75 0 0 1-1.543-2.575Zm1.763.707a.25.25 0 0 0-.44 0L1.698 13.132a.25.25 0 0 0 .22.368h12.164a.25.25 0 0 0 .22-.368Zm.53 3.996v2.5a.75.75 0 0 1-1.5 0v-2.5a.75.75 0 0 1 1.5 0ZM9 11a1 1 0 1 1-2 0 1 1 0 0 1 2 0Z"></path>
# </svg>
#     <button type="button" class="flash-close js-ajax-error-dismiss" aria-label="Dismiss error">
#       <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-x">
#     <path d="M3.72 3.72a.75.75 0 0 1 1.06 0L8 6.94l3.22-3.22a.749.749 0 0 1 1.275.326.749.749 0 0 1-.215.734L9.06 8l3.22 3.22a.749.749 0 0 1-.326 1.275.749.749 0 0 1-.734-.215L8 9.06l-3.22 3.22a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042L6.94 8 3.72 4.78a.75.75 0 0 1 0-1.06Z"></path>
# </svg>
#     </button>
#     You can’t perform that action at this time.
#   </div>
#
#     <template id="site-details-dialog">
#   <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open>
#     <summary role="button" aria-label="Close dialog"></summary>
#     <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
#       <button class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" type="button" aria-label="Close dialog" data-close-dialog>
#         <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-x">
#     <path d="M3.72 3.72a.75.75 0 0 1 1.06 0L8 6.94l3.22-3.22a.749.749 0 0 1 1.275.326.749.749 0 0 1-.215.734L9.06 8l3.22 3.22a.749.749 0 0 1-.326 1.275.749.749 0 0 1-.734-.215L8 9.06l-3.22 3.22a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042L6.94 8 3.72 4.78a.75.75 0 0 1 0-1.06Z"></path>
# </svg>
#       </button>
#       <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
#     </details-dialog>
#   </details>
# </template>
#
#     <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;">
#   <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
#   </div>
# </div>
#
#     <template id="snippet-clipboard-copy-button">
#   <div class="zeroclipboard-container position-absolute right-0 top-0">
#     <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0" data-copy-feedback="Copied!" data-tooltip-direction="w">
#       <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-copy js-clipboard-copy-icon m-2">
#     <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 0 1 0 1.5h-1.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-1.5a.75.75 0 0 1 1.5 0v1.5A1.75 1.75 0 0 1 9.25 16h-7.5A1.75 1.75 0 0 1 0 14.25Z"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0 1 14.25 11h-7.5A1.75 1.75 0 0 1 5 9.25Zm1.75-.25a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Z"></path>
# </svg>
#       <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2">
#     <path d="M13.78 4.22a.75.75 0 0 1 0 1.06l-7.25 7.25a.75.75 0 0 1-1.06 0L2.22 9.28a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L6 10.94l6.72-6.72a.75.75 0 0 1 1.06 0Z"></path>
# </svg>
#     </clipboard-copy>
#   </div>
# </template>
# <template id="snippet-clipboard-copy-button-unpositioned">
#   <div class="zeroclipboard-container">
#     <clipboard-copy aria-label="Copy" class="ClipboardButton btn btn-invisible js-clipboard-copy m-2 p-0 d-flex flex-justify-center flex-items-center" data-copy-feedback="Copied!" data-tooltip-direction="w">
#       <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-copy js-clipboard-copy-icon">
#     <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 0 1 0 1.5h-1.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-1.5a.75.75 0 0 1 1.5 0v1.5A1.75 1.75 0 0 1 9.25 16h-7.5A1.75 1.75 0 0 1 0 14.25Z"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0 1 14.25 11h-7.5A1.75 1.75 0 0 1 5 9.25Zm1.75-.25a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Z"></path>
# </svg>
#       <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none">
#     <path d="M13.78 4.22a.75.75 0 0 1 0 1.06l-7.25 7.25a.75.75 0 0 1-1.06 0L2.22 9.28a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L6 10.94l6.72-6.72a.75.75 0 0 1 1.06 0Z"></path>
# </svg>
#     </clipboard-copy>
#   </div>
# </template>
#
#
#
#
#     </div>
#
#     <div id="js-global-screen-reader-notice" class="sr-only mt-n1" aria-live="polite" aria-atomic="true" ></div>
#     <div id="js-global-screen-reader-notice-assertive" class="sr-only mt-n1" aria-live="assertive" aria-atomic="true"></div>
#   </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup

# URL of the GitHub Marketplace Actions page
url = 'https://github.com/marketplace?type=actions'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all action cards on the page
    actions = soup.find_all('div', class_='h3 lh-condensed')

    # Loop through each action and extract its name and link
    for action in actions:
        action_name = action.get_text(strip=True)
        action_link = 'https://github.com' + action.find('a')['href']
        print(f'Action Name: {action_name}')
        print(f'Action Link: {action_link}\n')
else:
    print(f'Failed to retrieve page, status code: {response.status_code}')
# Out:
# Failed to retrieve page, status code: 400

# %%
import requests
requests.post("https://github.com/marketplace?type=actions")
# Out:
# <Response [403]>

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# Base URL for GitHub Marketplace Actions
BASE_URL = "https://github.com/marketplace?type=actions"

# Define headers to mimic a real browser request
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36 Edge/91.0.864.64",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-US,en;q=0.9",
    "Connection": "keep-alive",
    "Upgrade-Insecure-Requests": "1",
    "Referer": "https://github.com/",
    "TE": "Trailers"
}

# Open a CSV file to store the scraped data
with open('github_marketplace_actions.csv', mode='w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['product_name', 'description', 'url', 'page_number']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()

    # Define the total number of pages you wish to scrape (adjust this based on the total product count)
    total_pages = 10  # Example: if each page has about 100 products, 10 pages would be around 1000 products

    for page in range(1, total_pages + 1):
        # Construct URL for the current page; GitHub Marketplace uses a page parameter
        page_url = f"{BASE_URL}&page={page}"
        print(f"Processing: {page_url}")

        try:
            response = requests.get(page_url, headers=HEADERS)
            if response.status_code != 200:
                print(f"Failed to retrieve page {page}. Status code: {response.status_code}")
                continue

            # Parse the content with BeautifulSoup
            soup = BeautifulSoup(response.text, 'html.parser')

            # --- Parsing the page ---
            # Note: The exact HTML structure may vary.
            # In this example, we assume each product is in a <div> (or similar container) that includes:
            #   - an <a> tag with class 'btn-link' for the product name and link,
            #   - a <p> tag containing the product description.
            #
            # Adjust the selectors based on the current page layout.

            # This is one way to search; you might need to inspect the HTML to find a more precise container.
            product_containers = soup.find_all('div', class_='flex-1')
            if not product_containers:
                print(f"No products found on page {page}. Check the HTML selectors.")
                continue

            for product in product_containers:
                # Extract product name and URL
                print(product)
                product_link = product.find('a', class_='btn-link')
                print(product_link)
                if product_link:
                    product_name = product_link.get_text(strip=True)
                    relative_link = product_link.get('href')
                    product_url = f"https://github.com{relative_link}" if relative_link else "N/A"
                else:
                    product_name = "N/A"
                    product_url = "N/A"

                # Extract a short description; adjust the tag/class as necessary.
                description_tag = product.find('p')
                description = description_tag.get_text(strip=True) if description_tag else "N/A"

                # Write the extracted data to the CSV file
                writer.writerow({
                    'product_name': product_name,
                    'description': description,
                    'url': product_url,
                    'page_number': page
                })

            print(f"Completed page {page}")
            # Introduce a delay to avoid overloading the server
            time.sleep(2)

        except Exception as e:
            print(f"An error occurred on page {page}: {e}")
# Out:
# Processing: https://github.com/marketplace?type=actions&page=1
# <div class="flex-1">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target js-nav-padding-recalculate js-header-menu-toggle Button--link Button--medium Button d-lg-none color-fg-inherit p-1" data-view-component="true" type="button"> <span class="Button-content">
# <span class="Button-label"><div class="HeaderMenu-toggle-bar rounded my-1"></div>
# <div class="HeaderMenu-toggle-bar rounded my-1"></div>
# <div class="HeaderMenu-toggle-bar rounded my-1"></div></span>
# </span>
# </button>
# </div>
# None
# <div class="flex-1 flex-order-2 text-right">
# <a class="HeaderMenu-link HeaderMenu-button d-inline-flex d-lg-none flex-order-1 f5 no-underline border color-border-default rounded-2 px-2 py-1 color-fg-inherit js-prevent-focus-on-mobile-nav" data-analytics-event='{"category":"Marketing nav","action":"click to Sign in","label":"ref_page:Marketing;ref_cta:Sign in;ref_loc:Header"}' data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header menu","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/marketplace?type=actions&amp;page=1","user_id":null}}' data-hydro-click-hmac="f6edb87bb8861af3d1189a5a768daa49ea08d9d26a00169c4a816a6e98cc984a" href="/login?return_to=https%3A%2F%2Fgithub.com%2Fmarketplace%3Ftype%3Dactions%26page%3D1">
#             Sign in
#           </a>
# </div>
# None
# <div class="d-flex flex-1"></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/trufflehog-oss">TruffleHog OSS</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Scan Github Actions with TruffleHog
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/metrics-embed">Metrics embed</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">An infographics generator with 40+ plugins and 300+ options to display stats about your GitHub account
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/yq-portable-yaml-processor">yq - portable yaml processor</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">create, read, update, delete, merge, validate and do more with yaml
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/super-linter">Super-Linter</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Super-linter is a ready-to-run collection of linters and code analyzers, to help validate your source code
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/gosec-security-checker">Gosec Security Checker</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Runs the gosec security checker
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/rebuild-armbian-and-kernel">Rebuild Armbian and Kernel</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Support Amlogic, Rockchip and Allwinner boxes
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/opencommit-improve-commits-with-ai">OpenCommit — improve commits with AI 🧙</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Replaces lame commit messages with meaningful AI-generated messages when you push to remote
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/checkout">Checkout</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Checkout a Git repository at a particular version
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/ssh-remote-commands">SSH Remote Commands</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Executing remote ssh commands
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/github-pages-action">GitHub Pages action</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">GitHub Actions for GitHub Pages 🚀 Deploy static files and publish your site easily. Static-Site-Generators-friendly
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/cache">Cache</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Cache artifacts like dependencies and build outputs to improve workflow execution time
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/generate-snake-game-from-github-contribution-grid">generate-snake-game-from-github-contribution-grid</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Generates a snake game from a github user contributions grid. Output the animation as gif or svg
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/build-and-push-docker-images">Build and push Docker images</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Build and push Docker images with Buildx
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/gh-release">GH Release</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Github Action for creating Github Releases
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/run-digger">run-digger</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Manage terraform collaboration
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/rebuild-armbian">Rebuild Armbian</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Build Armbian Linux
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/github-script">GitHub Script</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Run simple scripts using the GitHub client
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/deploy-to-github-pages">Deploy to GitHub Pages</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">This action will handle the deployment process of your project to GitHub Pages
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/chatgpt-codereviewer">ChatGPT CodeReviewer</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">A Code Review Action Powered By ChatGPT
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/ftp-deploy">FTP Deploy</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Automate deploying websites and more with this GitHub action via FTP and FTPS
# </p></div>
# None
# Completed page 1
# Processing: https://github.com/marketplace?type=actions&page=2
# <div class="flex-1">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target js-nav-padding-recalculate js-header-menu-toggle Button--link Button--medium Button d-lg-none color-fg-inherit p-1" data-view-component="true" type="button"> <span class="Button-content">
# <span class="Button-label"><div class="HeaderMenu-toggle-bar rounded my-1"></div>
# <div class="HeaderMenu-toggle-bar rounded my-1"></div>
# <div class="HeaderMenu-toggle-bar rounded my-1"></div></span>
# </span>
# </button>
# </div>
# None
# <div class="flex-1 flex-order-2 text-right">
# <a class="HeaderMenu-link HeaderMenu-button d-inline-flex d-lg-none flex-order-1 f5 no-underline border color-border-default rounded-2 px-2 py-1 color-fg-inherit js-prevent-focus-on-mobile-nav" data-analytics-event='{"category":"Marketing nav","action":"click to Sign in","label":"ref_page:Marketing;ref_cta:Sign in;ref_loc:Header"}' data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header menu","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/marketplace?type=actions&amp;page=2","user_id":null}}' data-hydro-click-hmac="3b0815b8febf6851fb5cd3350cc6a2b7a5fa071e8b9831cb4ff239272b4ce0d4" href="/login?return_to=https%3A%2F%2Fgithub.com%2Fmarketplace%3Ftype%3Dactions%26page%3D2">
#             Sign in
#           </a>
# </div>
# None
# <div class="d-flex flex-1"></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/setup-node-js-environment">Setup Node.js environment</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Setup a Node.js environment by adding problem matchers and optionally downloading and adding it to the PATH
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/run-ansible-lint">run-ansible-lint</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Run Ansible Lint
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/fastpages-an-easy-to-use-blogging-platform-with-support-for-jupyter-notebooks">fastpages: An easy to use blogging platform with support for Jupyter Notebooks.</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Converts Jupyter notebooks and Word docs into Jekyll blog posts
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/release-drafter">Release Drafter</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Drafts your next release notes as pull requests are merged into master
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/profile-readme-development-stats">Profile Readme Development Stats</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Are you an early 🐤 or a night 🦉? When are you most productive during the day? Let s check out in your readme
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/upload-a-build-artifact">Upload a Build Artifact</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Upload a build artifact that can be used by subsequent workflow steps
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/debugging-with-tmate">Debugging with tmate</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Debug your GitHub Actions Environment interactively by using SSH or a Web shell
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/blog-post-workflow">Blog Post Workflow</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Allows you to show your latest blog posts on your github profile or project readme
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/setup-php-action">Setup PHP Action</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">GitHub Action for PHP
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/typos-action">typos-action</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Run typos to check spelling in GitHub actions
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/github-profile-summary-cards">GitHub-Profile-Summary-Cards</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Generate profile summary cards and commit to default branch
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/hercules-insights">Hercules Insights</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Run various Git history analyses with src-d/hercules
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/wemake-python-styleguide">wemake-python-styleguide</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Runs wemake-python-styleguide as a Github Action
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/configure-aws-credentials-action-for-github-actions">"Configure AWS Credentials" Action for GitHub Actions</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Configures AWS credentials for use in subsequent steps in a GitHub Action workflow
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/paths-changes-filter">Paths Changes Filter</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Execute your workflow steps only if relevant files are modified
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/flutter-action">Flutter action</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Setup your runner with Flutter environment
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/create-pull-request">Create Pull Request</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Creates a pull request for changes to your repository in the actions workspace
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/git-auto-commit">Git Auto Commit</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Automatically commits files which have been changed during the workflow run and push changes back to remote repository
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/labeler">Labeler</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Automatically label new pull requests based on the paths of files being changed
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/make-openwrt">Make OpenWrt</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Support Amlogic, Rockchip and Allwinner boxes
# </p></div>
# None
# Completed page 2
# Processing: https://github.com/marketplace?type=actions&page=3
# <div class="flex-1">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target js-nav-padding-recalculate js-header-menu-toggle Button--link Button--medium Button d-lg-none color-fg-inherit p-1" data-view-component="true" type="button"> <span class="Button-content">
# ...
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/publish-docker">Publish Docker</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Uses the git branch as the docker tag and pushes the container
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/first-interaction">First interaction</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Greet new contributors when they create their first issue or open their first pull request
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/on-demand-self-hosted-aws-ec2-runner-for-github-actions">On-demand self-hosted AWS EC2 runner for GitHub Actions</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">GitHub Action for automatic creation and registration AWS EC2 instance as a GitHub Actions self-hosted runner
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/ai-code-review-action">AI Code Review Action</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Perform code reviews and comment on diffs using OpenAI API
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/release-changelog-builder">Release Changelog Builder</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">A GitHub action that builds your release notes / changelog fast, easy and exactly the way you want
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/automatic-releases">Automatic Releases</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Automate the GitHub release process with assets, changelogs, pre-releases, and more
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/download-workflow-artifact">Download workflow artifact</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Download and extract an artifact associated with given workflow and commit or other criteria
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/create-or-update-comment">Create or Update Comment</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Create or update an issue or pull request comment
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/swift-create-xcframework">swift-create-xcframework</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Creates XCFramework bundles for the products in your Swift Package and uploads them as Artifacts you can attach to a
# release
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/deploy-to-firebase-hosting">Deploy to Firebase Hosting</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">A GitHub Action to deploy to Firebase Hosting
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/deploy-github-pages-site">Deploy GitHub Pages site</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">A GitHub Action to deploy an artifact as a GitHub Pages site
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/run-on-architecture">Run on architecture</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Run commands in a Linux container with a specific CPU architecture (armv6, armv7, aarch64, s390x, ppc64le)
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/twitter-together">Twitter, together!</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Collaborate on tweets just like you collaborate on code, using pull requests
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/automatic-rebase">Automatic Rebase</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Automatically rebases PR on /rebase comment
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/gradle-build-action">Gradle Build Action</a><svg aria-hidden="true" class="Octicon-sc-9kayk9-0 kwlIRP fgColor-accent" fill="currentColor" focusable="false" height="16" style="display:inline-block;user-select:none;vertical-align:text-bottom;overflow:visible" viewbox="0 0 16 16" width="16"><path d="m9.585.52.929.68c.153.112.331.186.518.215l1.138.175a2.678 2.678 0 0 1 2.24 2.24l.174 1.139c.029.187.103.365.215.518l.68.928a2.677 2.677 0 0 1 0 3.17l-.68.928a1.174 1.174 0 0 0-.215.518l-.175 1.138a2.678 2.678 0 0 1-2.241 2.241l-1.138.175a1.17 1.17 0 0 0-.518.215l-.928.68a2.677 2.677 0 0 1-3.17 0l-.928-.68a1.174 1.174 0 0 0-.518-.215L3.83 14.41a2.678 2.678 0 0 1-2.24-2.24l-.175-1.138a1.17 1.17 0 0 0-.215-.518l-.68-.928a2.677 2.677 0 0 1 0-3.17l.68-.928c.112-.153.186-.331.215-.518l.175-1.14a2.678 2.678 0 0 1 2.24-2.24l1.139-.175c.187-.029.365-.103.518-.215l.928-.68a2.677 2.677 0 0 1 3.17 0ZM7.303 1.728l-.927.68a2.67 2.67 0 0 1-1.18.489l-1.137.174a1.179 1.179 0 0 0-.987.987l-.174 1.136a2.677 2.677 0 0 1-.489 1.18l-.68.928a1.18 1.18 0 0 0 0 1.394l.68.927c.256.348.424.753.489 1.18l.174 1.137c.078.509.478.909.987.987l1.136.174a2.67 2.67 0 0 1 1.18.489l.928.68c.414.305.979.305 1.394 0l.927-.68a2.67 2.67 0 0 1 1.18-.489l1.137-.174a1.18 1.18 0 0 0 .987-.987l.174-1.136a2.67 2.67 0 0 1 .489-1.18l.68-.928a1.176 1.176 0 0 0 0-1.394l-.68-.927a2.686 2.686 0 0 1-.489-1.18l-.174-1.137a1.179 1.179 0 0 0-.987-.987l-1.136-.174a2.677 2.677 0 0 1-1.18-.489l-.928-.68a1.176 1.176 0 0 0-1.394 0ZM11.28 6.78l-3.75 3.75a.75.75 0 0 1-1.06 0L4.72 8.78a.751.751 0 0 1 .018-1.042.751.751 0 0 1 1.042-.018L7 8.94l3.22-3.22a.751.751 0 0 1 1.042.018.751.751 0 0 1 .018 1.042Z"></path></svg></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Configures Gradle for GitHub actions, caching state and generating a dependency graph via Dependency Submission
# </p></div>
# None
# <div class="flex-1" data-testid="non-featured-item" style="min-width:0"><div class="d-flex flex-justify-between flex-items-start gap-3"><h3 class="d-flex f4 lh-condensed prc-Heading-Heading-6CmGO"><a class="marketplace-common-module__marketplace-item-link--jrIHf line-clamp-1" href="/marketplace/actions/flank">Flank</a></h3><span class="prc-Label-Label--LG6X" data-size="small" data-testid="listing-type-label" data-variant="secondary">Action</span></div><p class="mt-1 mb-0 text-small fgColor-muted line-clamp-2">Run Flank from Github actions
# </p></div>
# None
# Completed page 7

# %% [markdown]
# #Question 5 (20 points)
#
# PART 1:
# Web Scrape  tweets from Twitter using the Tweepy API, specifically targeting hashtags related to subtopics (machine learning or artificial intelligence.)
# The extracted data includes the tweet ID, username, and text.
#
# Part 2:
# Perform data cleaning procedures
#
# A final data quality check ensures the completeness and consistency of the dataset. The cleaned data is then saved into a CSV file for further analysis.
#
#
# **Note**
#
# 1.   Follow tutorials provided in canvas to obtain api keys. Use ChatGPT to get the code. Make sure the file is downloaded and saved.
# 2.   Make sure you divide GPT code as shown in tutorials, dont make multiple requestes.

# %%
############################################
# PART 1: TWITTER SCRAPING WITH TWEEPY (v2)
############################################

# 1. INSTALL AND IMPORT LIBRARIES
# (Uncomment the pip installs if needed)
# !pip install tweepy pandas

import tweepy
import pandas as pd
import re

# 2. AUTHENTICATE WITH TWITTER API (v2)
# Replace placeholders with your actual credentials, including the Bearer Token
bearer_token = "AAAAAAAAAAAAAAAAAAAAAHmpzQEAAAAADh7vckrj6GLxxQXkR6Ym9XIhwOw%3DsjWJpR4OzVcs6goQcBBbbJoL9lTlbN9zN4VklnXsgfdviJ7sUL"
consumer_key = "DlI1s61j2pO8dAp2WJozzGv70"
consumer_secret = "8ug40WbwLriQ8rXu7Tq8erhrEw2o4vaDOkGu4PoKyU06XLmtTV"
access_token = "1892415559066701825-muK8S8GJk9vL7OyVbiI4XS66LyCe69"
access_token_secret = "ddjhMGjcZq1tHJIajn8IIRWDTcKU3X7D2D0yNhPozIIzj"
# Initialize Tweepy Client for v2
client = tweepy.Client(
    bearer_token=bearer_token,
    consumer_key=consumer_key,
    consumer_secret=consumer_secret,
    access_token=access_token,
    access_token_secret=access_token_secret,
    # If you often hit rate limits, set this to True to have Tweepy sleep until reset
    wait_on_rate_limit=True
)

# 3. SEARCH TWEETS WITH SPECIFIC HASHTAGS
# We can use Twitter’s “recent search” endpoint for v2 (tweets from last 7 days).
# The '-is:retweet' filter removes retweets.
# Use 'lang:en' to filter English, plus #machinelearning or #AI hashtags.
query = "#machinelearning OR #AI -is:retweet lang:en"

# The free tier allows max_results up to 10 for "Essential" (check current Twitter rules).
# If you have a higher tier or academic access, you can go up to 100 per request.
response = client.search_recent_tweets(
    query=query,
    max_results=10,  # 10 is often the max if you're on the free tier
    tweet_fields=["id", "text", "author_id", "created_at"]
)

# response.data is a list of Tweet objects (or None if no tweets found)
tweets_data = response.data if response.data else []

# 4. EXTRACT FIELDS (TWEET ID, USER ID, TEXT, ETC.)
data_list = []
for tweet in tweets_data:
    tweet_id = tweet.id
    author_id = tweet.author_id
    tweet_text = tweet.text
    created_at = tweet.created_at

    data_list.append({
        "tweet_id": tweet_id,
        "author_id": author_id,
        "text": tweet_text,
        "created_at": created_at
    })

# 5. CONVERT TO DATAFRAME
df = pd.DataFrame(data_list)

############################################
# PART 2: BASIC DATA CLEANING
############################################

# Simple text cleaner: remove URLs, convert to lowercase, remove special chars
def clean_text(text):
    # Remove URLs
    text_no_urls = re.sub(r"http\S+|www\S+|https\S+", "", text, flags=re.MULTILINE)
    # Remove non-alphanumeric chars except spaces, #, and @ (optional)
    text_alpha = re.sub(r"[^A-Za-z0-9\s#@]", "", text_no_urls)
    # Lowercase
    text_cleaned = text_alpha.lower()
    return text_cleaned.strip()

df["clean_text"] = df["text"].apply(clean_text)

# Data Quality
# Drop duplicates if any (by tweet_id)
df.drop_duplicates(subset="tweet_id", keep="first", inplace=True)

############################################
# PART 3: SAVE CLEANED DATA TO CSV
############################################

output_filename = "twitter_ai_ml_tweets_v2.csv"
df.to_csv(output_filename, index=False, encoding="utf-8")
print(f"Saved cleaned tweets to {output_filename}")

print("Final DataFrame:")
print(df)
# Out:
# Saved cleaned tweets to twitter_ai_ml_tweets_v2.csv
# Final DataFrame:
#               tweet_id            author_id  \
# 0  1892424569065029649            253682939
# 1  1892424558172655855  1882134432196542465
# 2  1892424555022713117   892438929525178368
# 3  1892424547254882747  1682288478351159297
# 4  1892424497271071077            168449286
# 5  1892424495954075842  1806403041622646785
# 6  1892424492548575252  1815346492410052608
# 7  1892424484344189074  1857426414561087488
# 8  1892424475318063167  1682288478351159297
# 9  1892424443382935618  1623124126939619328
#
#                                                 text  \
# 0  🔒 Privacy is a top priority! DeepSearch uses z...
# 1  AI agents on blockchain offer a new paradigm f...
# 2  #BE #ME #BestEngineeringcollege #Ece #Electron...
# 3  ✨ Just found this stunning AI creation on #CoS...
# 4  Imagine a tool that lets business leaders spea...
# 5  🏃 I’ve just started earning Bytes on @despeedn...
# 6  ✨ Just found this stunning AI creation on #CoS...
# 7  @RealAlexJones BREAKING: PublicAI training AI ...
# 8  ✨ Just found this stunning AI creation on #CoS...
# 9  Changing the narrative from DYOR to DIFM (Do i...
#
#                  created_at                                         clean_text
# 0 2025-02-20 04:02:31+00:00  privacy is a top priority deepsearch uses zksn...
# 1 2025-02-20 04:02:28+00:00  ai agents on blockchain offer a new paradigm f...
# 2 2025-02-20 04:02:28+00:00  #be #me #bestengineeringcollege #ece #electron...
# 3 2025-02-20 04:02:26+00:00  just found this stunning ai creation on #coscr...
# 4 2025-02-20 04:02:14+00:00  imagine a tool that lets business leaders spea...
# 5 2025-02-20 04:02:14+00:00  ive just started earning bytes on @despeednet ...
# 6 2025-02-20 04:02:13+00:00  just found this stunning ai creation on #coscr...
# 7 2025-02-20 04:02:11+00:00  @realalexjones breaking publicai training ai t...
# 8 2025-02-20 04:02:09+00:00  just found this stunning ai creation on #coscr...
# 9 2025-02-20 04:02:01+00:00  changing the narrative from dyor to difm do it...

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %% [markdown]
# It was a fascinating task, for me at least, to pull information from different pages. My biggest obstacle was the limits imposed by GitHub on making API requests. Collecting the data set and automating the process was something I found interesting, along with using the BeautifulSoup library. The time allocation was more than adequate, but rectifying the mistakes was much more tedious than I had hoped. If there was any additional time, I could have rewritten portions of the code in a way that would have reduced the number of errors being produced.

# %% [markdown]
# # Write your response below
# Fill out survey and provide your valuable feedback.
#
# https://docs.google.com/forms/d/e/1FAIpQLSd_ObuA3iNoL7Az_C-2NOfHodfKCfDzHZtGRfIker6WyZqTtA/viewform?usp=dialog
